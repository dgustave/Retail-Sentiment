# %%
import numpy as np, pandas as pd, math, os
from PIL import Image

# %%
import pytesseract

# %%
import pprint as p

# %%
pred = pytesseract.image_to_string("trader.jpg")

# %%
type(pred)
# Out:
# str

# %%
print(pred)
# Out:
# Accounts
#
# $1,783.03 $965.94 (18.22%)
#
# Day Day
# Symbol gain $ gain % Price Chg $ Chg % Mkt value Gain$ v Gain %
# BYND Aug 2
#
# 2019185 Put | g45.00 241.42% 11.95 845 241.42% 1,196.00 395.33 49.43%
# (Weekly)
# 1
#
#
#
# 2019 25 Put 143.14 140.52% 2.45 1.43 140.52% 245.00 167.33 215.43%
#
# VBTX Aug 16
# 1

# %%
pred0 = pytesseract.image_to_string("New folder/0.jpg")

# %%
print(pred0)
# Out:
# Type
# Trades
# DATE
#
# Today
#
# Today
#
# Today
#
# oO
# ol
# Dashboard
#
# Day Range
#
# Today
# TRANSACTION CHANGE
# BYND Aug 2 2019 185.00 W Put Sell to
# Close 1 @ 14.00 es
# MMDA1 Cash Alternatives Purchase 24.51
# Cash Alternatives Purchase -24.51
#
# @ 2 Ss =
#
# Watch Lists Accounts Trade More

# %%
pred1 = pytesseract.image_to_string("New folder/1.jpg")

# %%
pred2 = pytesseract.image_to_string("New folder/2.png")

# %%
pred3 = pytesseract.image_to_string("New folder/3.jpg")
pred4 = pytesseract.image_to_string("New folder/4.png")
pred5 = pytesseract.image_to_string("New folder/5.png")

# %%
print(pred1)
# Out:
# eI $15,900.00
#
# P/L Open $15,900.00

# %%
print(pred3)
# Out:
#
#
# $1,823.78 $299.07 (19.61%)
#
#
#
#
#
#
#
#
#
# Day Day
#
# Symbol gain $ gain % Price Chg $ Chg % Mkt value Gain$ vw Gain %
# VBTX Aug 16
#
# 2012 25 Put 118.82 94.16% 2.45 1.18 94.16% 245.00 167.33 215.43%
# Tocd Aug 16
#
# ae 11 Call 99.84 124.55% 0.30 0.1664 124.55% 180.00 57.89 47.40%
# PXLW Aug 16
#
# 2019 2.5 Call 42.60 20.79% 0.825 0.142 20.79% 247.50 37.40 17.80%
# AMD Aug 16
#
# 2019 30Call ~-38.02 -16.45% 0.965 -0.1901 -16.45% 193.00 25.00 14.88%

# %%
print(pred4)
# Out:
# 9:55 >a)
#
# < $200.19 @
#
# AAPL
#
# Featured In
#
# Computer Hardware 32 Retail 1,280 Mediz
#
# 100 Most Popular 100 Telecommunications
#
# Computer Software 25 Electronics 510
#
# Technology 1,800 Consumer Products 558
# Your History
#
# Aug 8, 2019
#
#
#
# $202.5 Call 8/9 Buy
#
# $36.00 >
# Aug 7, 2019
#
#
#
# $202.5 Call 8/9 Buy
# Aug 7, 2019
#
# TODAY'S VOLUME
# 4,109,056 ee
#
# Canceled >
#
#
#
# 32:
#
# Tel

# %%
print(pred5)
# Out:
# 11:58 a 2
#
# View MCD
#
# MCD $220 Call 9/6 Sell
#
# Good for day
#
# Aug 8, 2019
#
# Limit Sell
#
# Close
#
# Aug 8, 2019 at 11:58 AM ET
# 1 contract at $3.40
#
# $340.00
#
# go

# %%
pred2a = pytesseract.image_to_string("New folder/2a.png")

# %%
print(pred2a)
# Out:
# Symbol
#
# @ SPY
#
# @ SHOP
#
# @ SPY
#
# @ SHOP [im]
#
# 0 Aug2
# 0 Aug2
# VN
#
# MN
#
# oT
#
# Od
#
# of}
#
# Od
#
# vac
#
# 340
#
# v2}
#
# 330
#
# I
#
# P/L Open
# 0.00
#
# 0.00
# 32.00
# 457.00
#
# 7A EW]
# 82.51
# lee
# 32.00
# 457.00

# %%
app = pytesseract.image_to_string("New folder/lilApple.jpg")

# %%
print(app)
# Out:
# < $207.52 @
#
# AAPL
# 100 Most Popular 100 Telecommunications 32:
#
# Computer Software 25 Electronics 509 Te!
#
# Technology 1,796 Consumer Products 558
#
# Your History
#
# $205 Call 8/16 Sell $370.00 >
# Aug 13, 2019
#
# >
# Aug 12, 2019
#
#
#
# Apple play this-morning!!
#
# AUG TZ, ZU
#
# $205 Call 8/16 Buy $125.00 >
# Aug 12, 2019
#
# SHOW MORE
#
# TODAY'S VOLUME Se
#
# 6,081,167 ohh
# e
#
# Q
