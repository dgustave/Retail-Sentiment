# %%
import pandas as pd, numpy as np
import plotly.express as px

# %%
df = pd.read_csv("allDataDF2.csv", encoding="utf8")

# %%
df
# Out:
#        Unnamed: 0                  id              name  \
# 0               0  488359813160501251      Merente#5844
# 1               1  689681229989150742    jackaplan#7289
# 2               2  131952052069728258       Teecee#3022
# 3               3  464449226521313292  TradingJEDI#2647
# 4               4  399198468159045633    AjKilgore#0424
# ...           ...                 ...               ...
# 28023       52302  494525003484889088          Pat#0465
# 28024       52303  503741265448271893   itsluis337#7090
# 28025       52306  494525003484889088          Pat#0465
# 28026       52307  159985870458322944         MEE6#4876
# 28027       52308  740072202413801512        K Doc#3110
#
#                                                  content  \
# 0      Thanks <@464449226521313292> !  I opted for th...
# 1      Barely followed the market at all today (didn’...
# 2                     <@!464449226521313292> thanks boss
# 3      <@!399198468159045633> BRO AWSOME SO GLAD YOU ...
# ...

# %%
fig = px.histogram(df, x="enhancedSentiment", y="positiveScore")
fig.show()
