# %%
import numpy as np, math, re
import pandas as pd, sqlite3
import datetime, time, nltk
import matplotlib.pyplot as plt
from nltk import sentiment

# %%
import emoji
import emosent

# %%
sia = sentiment.SentimentIntensityAnalyzer()

# %%
current_lex = sia.make_lex_dict()

# %%
clex_dic = {"Words": current_lex.keys(),
"Score": current_lex.values()}

# %%
lex_df = pd.DataFrame(clex_dic)

# %%
lex_df.sort_values("Score").tail(30)
# Out:
#               Words  Score
# 4223         joyous    3.1
# 931         awesome    3.1
# 4561    masterpiece    3.1
# 307             lyl    3.1
# 5052     perfectest    3.1
# 3413          great    3.1
# 5025   peacefullest    3.1
# 2655     excellence    3.1
# 76              143    3.2
# 1054           best    3.2
# 3525       happiest    3.2
# 3415       greatest    3.2
# 1366   cheerfullest    3.2
# 5068      perfectly    3.2
# 3070        freedom    3.2
# 2634       euphoric    3.2
# 4448       lovingly    3.2
# 4983       paradise    3.2
# 3285           glee    3.2
# 4439           love    3.2
# 3308       glorious    3.2
# 2492         elated    3.2
# 2470        ecstacy    3.3
# 6539     sweetheart    3.3
# 2633       euphoria    3.3
# 305             lya    3.3
# 4541  magnificently    3.4
# 205             aml    3.4
# 267             ilu    3.4
# 269             ily    3.4

# %%
conn = sqlite3.connect("data/discord/discord.db")

# %%
discord_comments_df = pd.read_sql("SELECT * FROM DiscordCommentsThursdayData", con=conn, index_col="index")

# %%
conn.close()

# %%
discord_comments_df.tail()
# Out:
#                        ID                Name  \
# index
# 5076   663395442645663764         stocky#9277
# 5077   449633258116874250      dakotared#3395
# 5078   555027629036535819  Fill That Gap#0777
# 5079   674648888279302204       GOOFYSPY#8332
# 5080   540290732708069393      J. Gatsby#2868
#
#                                                  Message             Time  \
# index
# 5076                                               $rope  20:58:05.959000
# 5077   quick scalp on $SCWX with Dell buying out the ...  18:48:28.342000
# 5078   $SGBX I was pretty sloppy on. Became patient w...  01:20:54.209000
# 5079                           $TSLA 💯DIS 💯 Uvxy 💯 QQQ 💯  21:13:57.291000
# 5080   @everyone If anyone was in Voice this morning ...  20:05:15.697000
#
#                                Datetime        Date  UnixTimeStamp  \
# index
# 5076   2020-05-01 20:58:05.959000+00:00  2020-05-01   1.588367e+09
# 5077   2019-12-23 18:48:28.342000+00:00  2019-12-23   1.577127e+09
# 5078   2020-10-17 01:20:54.209000+00:00  2020-10-17   1.602898e+09
# 5079   2020-02-27 21:13:57.291000+00:00  2020-02-27   1.582838e+09
# 5080   2020-08-20 20:05:15.697000+00:00  2020-08-20   1.597954e+09
#
#                               EasternDT  \
# index
# 5076   2020-05-01 15:58:05.959000-05:00
# 5077   2019-12-23 13:48:28.342000-05:00
# 5078   2020-10-16 20:20:54.209000-05:00
# 5079   2020-02-27 16:13:57.291000-05:00
# 5080   2020-08-20 15:05:15.697000-05:00
#
#                                                 Mentions  IsBot   Emojis  \
# index
# 5076                                                      Human
# 5077                                                      Human
# 5078                                                      Human
# 5079                                                      Human  💯 💯 💯 💯
# 5080   <@540290732708069393>, <@689681229989150742>, ...  Human
#
#       mentionedStock  Excam                   MentionedUsers MentionedStocks
# index
# 5076            ROPE      0
# 5077            SCWX      0                                    on, dell, out
# 5078            SGBX      0                                              out
# 5079            TSLA      0                                   dis, uvxy, qqq
# 5080   TSLA V Z PTON      1  J. Gatsby, jackaplan, Ant, NiKa   all, well, on

# %%
used_emojis = {}
def usedEmojis(emoj):
    if emoj == "": next
    used_emojis_list = emoji.emoji_lis(emoj)
    for emote in used_emojis_list:
        if emote["emoji"] in used_emojis.keys():      
            used_emojis[emote["emoji"]] += 1
        else:
            used_emojis[emote["emoji"]] = 1

# %%
emoji.emoji_lis("$TSLA")
# Out:
# []

# %%
discord_comments_df.Emojis.apply(usedEmojis)
# Out:
# index
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 5076    None
# 5077    None
# 5078    None
# 5079    None
# 5080    None
# Name: Emojis, Length: 5081, dtype: object

# %%
used_emojis
# Out:
# {'🐠': 2,
#  '🐟': 2,
#  '😦': 4,
#  '🤑': 34,
#  '🔥': 80,
#  '😭': 6,
#  '💦': 3,
#  '👍': 33,
#  '💴': 4,
#  '💰': 28,
#  '🙂': 24,
#  '🤯': 3,
#  '😢': 1,
#  '🎬': 2,
#  '😩': 1,
#  '😅': 5,
#  '💯': 24,
#  '😂': 50,
#  '😎': 9,
#  '🙌': 12,
#  '🏻': 26,
#  '😉': 23,
#  '👀': 11,
#  '🤗': 1,
#  '☝': 1,
#  '😱': 1,
#  '🏽': 6,
#  '🤔': 6,
#  '🤣': 9,
#  '😆': 4,
#  '💥': 3,
#  '👑': 1,
#  '🙏': 51,
#  '😋': 3,
#  '😘': 1,
#  '😲': 2,
#  '🚂': 3,
#  '😁': 6,
#  '😔': 1,
#  '👌': 18,
#  '\U0001f9c3': 3,
#  '🥺': 1,
#  '🤬': 1,
#  '🐢': 1,
#  '😄': 5,
#  '💪': 21,
#  '👆': 1,
#  '🇺': 1,
#  '🇸': 1,
#  '🐻': 1,
#  '🚨': 3,
#  '🧐': 2,
#  '🔑': 1,
#  '🤤': 1,
#  '💸': 5,
#  '🏃': 4,
#  '💵': 6,
#  '🐐': 5,
#  '🤙': 5,
#  '🏦': 1,
#  '😳': 12,
#  '😤': 2,
#  '💎': 4,
#  '🏿': 8,
#  '🚀': 6,
#  '✊': 3,
#  '🍻': 3,
#  '🥳': 5,
#  '🤘': 1,
#  '🤫': 4,
#  '📈': 2,
#  '😃': 2,
#  '🦕': 1,
#  '🏼': 36,
#  '❤': 6,
#  '🍳': 1,
#  '🏄': 2,
#  '🌊': 1,
#  '🚼': 1,
#  '✌': 2,
#  '😍': 4,
#  '🛥': 1,
#  '👩': 2,
#  '🚣': 1,
#  '♀': 1,
#  '💼': 1,
#  '🤷': 7,
#  '♂': 10,
#  '😊': 1,
#  '😒': 1,
#  '🖐': 1,
#  '🕵': 1,
#  '🐮': 1,
#  '🔔': 1,
#  '🤩': 3,
#  '🍔': 1,
#  '👇': 18,
#  '👉': 1,
#  '💨': 3,
#  '😬': 6,
#  '✅': 2,
#  '\U0001f9be': 1,
#  '🤦': 2,
#  '👏': 2,
#  '🥰': 2,
#  '🍎': 2,
#  '🎉': 1,
#  '🐧': 1,
#  '🏾': 5,
#  '🛫': 1,
#  '🎊': 1,
#  '📉': 1,
#  '🤠': 2,
#  '😏': 6,
#  '😓': 1,
#  '🤞': 1,
#  '🐳': 1,
#  '🌙': 1,
#  '🍺': 1,
#  '🤧': 1,
#  '🍼': 1,
#  '😴': 3,
#  '🇨': 1,
#  '🇳': 1,
#  '👐': 2,
#  '💠': 1,
#  '🧠': 1,
#  '🤝': 1,
#  '👨': 1,
#  '🏫': 1,
#  '😜': 1}

# %%
hasSentiment = {}
for k in list(used_emojis.keys()):
    try:
        projSent = emosent.get_emoji_sentiment_rank(k)
        projSent = projSent["sentiment_score"]
        hasSentiment[k] = projSent
    except:
        hasSentiment[k] = "No sentiment available."

# %%
hasSentiment
# Out:
# {'🐠': 0.462,
#  '🐟': 0.724,
#  '😦': -0.389,
#  '🤑': 'No sentiment available.',
#  '🔥': 0.14,
#  '😭': -0.093,
#  '💦': 0.476,
#  '👍': 0.522,
#  '💴': -0.25,
#  '💰': 0.256,
#  '🙂': 'No sentiment available.',
#  '🤯': 'No sentiment available.',
#  '😢': 0.007,
#  '🎬': 0.3,
#  '😩': -0.368,
#  '😅': 0.18,
#  '💯': 0.121,
#  '😂': 0.221,
#  '😎': 0.493,
#  '🙌': 0.56,
#  '🏻': 'No sentiment available.',
#  '😉': 0.464,
#  '👀': 0.063,
#  '🤗': 'No sentiment available.',
#  '☝': 0.314,
#  '😱': 0.19,
#  '🏽': 'No sentiment available.',
#  '🤔': 'No sentiment available.',
#  '🤣': 'No sentiment available.',
#  '😆': 0.412,
#  '💥': 0.149,
#  '👑': 0.701,
#  '🙏': 0.418,
#  '😋': 0.634,
#  '😘': 0.702,
#  '😲': -0.07,
#  '🚂': 0.308,
#  '😁': 0.45,
#  '😔': -0.146,
#  '👌': 0.564,
#  '\U0001f9c3': 'No sentiment available.',
#  '🥺': 'No sentiment available.',
#  '🤬': 'No sentiment available.',
#  '🐢': 0.216,
#  '😄': 0.422,
#  '💪': 0.556,
#  '👆': 0.333,
#  '🇺': 0.563,
#  '🇸': 0.527,
#  '🐻': 0.468,
#  '🚨': 0.673,
#  '🧐': 'No sentiment available.',
#  '🔑': 0.25,
#  '🤤': 'No sentiment available.',
#  '💸': 0.167,
#  '🏃': 0.415,
#  '💵': 0.423,
#  '🐐': 0.556,
#  '🤙': 'No sentiment available.',
#  '🏦': 1.0,
#  '😳': 0.018,
#  '😤': -0.211,
#  '💎': 0.569,
#  '🏿': 'No sentiment available.',
#  '🚀': 0.525,
#  '✊': 0.433,
#  '🍻': 0.521,
#  '🥳': 'No sentiment available.',
#  '🤘': 'No sentiment available.',
#  '🤫': 'No sentiment available.',
#  '📈': 0.5,
#  '😃': 0.558,
#  '🦕': 'No sentiment available.',
#  '🏼': 'No sentiment available.',
#  '❤': 0.746,
#  '🍳': 0.03,
#  '🏄': 0.564,
#  '🌊': 0.516,
#  '🚼': 0.667,
#  '✌': 0.464,
#  '😍': 0.678,
#  '🛥': 'No sentiment available.',
#  '👩': 0.074,
#  '🚣': 0.727,
#  '♀': 0.333,
#  '💼': 0.643,
#  '🤷': 'No sentiment available.',
#  '♂': 0.2,
#  '😊': 0.645,
#  '😒': -0.375,
#  '🖐': 'No sentiment available.',
#  '🕵': 'No sentiment available.',
#  '🐮': 0.628,
#  '🔔': 1.0,
#  '🤩': 'No sentiment available.',
#  '🍔': 0.286,
#  '👇': 0.255,
#  '👉': 0.394,
#  '💨': 0.391,
#  '😬': 0.196,
#  '✅': 0.431,
#  '\U0001f9be': 'No sentiment available.',
#  '🤦': 'No sentiment available.',
#  '👏': 0.521,
#  '🥰': 'No sentiment available.',
#  '🍎': 0.34,
#  '🎉': 0.74,
#  '🐧': 0.461,
#  '🏾': 'No sentiment available.',
#  '🛫': 'No sentiment available.',
#  '🎊': 0.727,
#  '📉': 0.5,
#  '🤠': 'No sentiment available.',
#  '😏': 0.332,
#  '😓': -0.081,
#  '🤞': 'No sentiment available.',
#  '🐳': 0.15,
#  '🌙': 0.621,
#  '🍺': 0.504,
#  '🤧': 'No sentiment available.',
#  '🍼': 0.625,
#  '😴': -0.081,
#  '🇨': 0.0,
#  '🇳': 0.0,
#  '👐': -0.024,
#  '💠': 0.0,
#  '🧠': 'No sentiment available.',
#  '🤝': 'No sentiment available.',
#  '👨': 0.571,
#  '🏫': -0.3,
#  '😜': 0.456}

# %%
emote_comments = discord_comments_df[discord_comments_df.Emojis != ""]

# %%
raw_messages = emote_comments.Message.values

# %%
raw_messages
# Out:
# array(['Just keep trimming trimming 🐠 🐟',
#        'I need some luck to see these gains. 😦',
#        '10 minutes in that play haha 🤑🤑',
#        'also shoutout to <@!579205396166737921> for the signal 🔥',
#        'So glad I got on BA😭', '💦💦💦',
#        'Tried selling but it did not go through 😦', 'Jeez nice 👍',
#        'Awesome <@367506726582484996> that’s why your name is purple. Patience pays 💴 💰',
#        'pog 🙂', 'noice 🙂', '🤯🤯🤯', 'But mine is a negative 😢',
#        'First day wakin up actually n tradin 🎬🎬fuckin movie',
#        'Those look nice!👍',
#        "<@579205396166737921> what's the difference between your spy and mine 😩",
#        '<@!432049873563680786> thank you for your 🔥🔥FIRE  List everyday!🔥🔥 Chatroom with voicechat and team members is really thatvwork',
#        'Btw I’m j a newbie, only 17yrs old😅',
#        'Made some lunch money while I’m in class 💯 shout-out <@!579205396166737921>',
#        '<@!432049873563680786> 👍 learning a lot. Got in on the close of the second candle. Have a lot more to learn still',
#        "I'm kinda mad that I did a spread instead of naked calls on WORK, But I'll take the $90 profit 🙂",
#        '@<@504078660857364480> Apparently u r not brokeass 😂',
#        'Just keep trimming trimming trimming 🐠 🐟',
#        '<@!464449226521313292>  😎',
#        'Made +$26 from SBUX calls, that’s about a 10.6% profit on what I invested.. I’m playing it small and happy with the gains/limit I’ve set myself... Thank you <@!524718950475628554> for the SBUX alert🙌🏻',
#        'Looks good 👍', 'hit my daily goal again 😉',
#        'Damn show me the way <@504078660857364480> <:Spitfire:653459285501804582> 🤑',
#        'how did you do it <@!504078660857364480>👀',
#        'Them big boi gainz 🔥', '30min 410. Ill take it 🤗',
#        'SBUX🔥🔥🔥🔥 let’s goooo <@504078660857364480>',
#        'Gotta thank <@622804945359339543> for this one ☝️',
#        'holy cow with the wow 😱',
#        '<@187734025887023104> Profits from the free signal🔥',
#        'And lulu 😉',
#        'Oh thank you <@597164927265800203> 😂 your pic just made me roll',
#        'From the dis signal, just upgraded 🔥', '👍',
#        'This was a no brainer but I still waited till <@!464449226521313292> called it. I held a little longer on my second leg of it so didn’t realize as much gains as he did but what nice profit. 👍🏽 thanks',
#        '(And yes, the right circle IS bigger than the left! picked up two Calls there 😂 )',
#        'Awesome 👍',
#        'Has anyone used indicator script from tradest.io? 🤔🤔🤔is it really that accurate?',
#        'You are the literal GOAT of the chat 🤣🤣🤣 <@294553563252785152> amazing world man you’re destroying this market no matter the direction',
#        'thanks <@!579205396166737921> & <@!432049873563680786>  - you guys have helped polish this turd right up! 😆',
#        '😂 😂  im your biggest fan bro <@!294553563252785152>',
#        'Rode the TSLA train up and back down. We have finally surpassed 100k 🙌🏻 Can’t even describe how much this group has changed my life. LETS GO BAYBEEE! #humble #greenisgood',
#        '<@!432049873563680786> the strategy works man, simple as that. It fits my style too - I spent the first 6mos of my studying on day trading pennies & quick reversals but PDT killed my game. Enter TM & Bueller’s watch list. BOOM 💥 I can find & manage my own plays everyday (aaand take softballs from your list!) and trade options all day on a cash account with now PDT!',
#        'if you trade my list there are no softballs, its all you! <@!294553563252785152> You have to swing the bat not me 😂  Either way we are an excellent team and I cant wait for next week!',
#        '👑 <@!149033260016467968>',
#        'Didn’t think ppl would wanna hold their positions over the weekend decided to try 100 on a spy put ended up with 800 😂',
#        'Thank you 🙏 <@!579205396166737921>',
#        'Oops nvm current balance is now $7608.23 🤑',
#        'Talk about a good day 🤑😋 300% gains',
#        'Thanks 🙏 <@!475450165096873987> <@565515276297175070>', '😘',
#        '🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥', '(had to crop the image 🙂 )',
#        'More than triple the money 🙂 loving BA',
#        '<@!494322262384836624> omg what are you buying? 🙂',
#        'Damn, you guys got quite the rap sheet!!😲😲',
#        'Regn train doesn’t stop 🚂 cut my last time. Now I’m letting one ride',
#        'Profit is profit 😁 learned that the hard way',
#        'I just joined this server, and I still haven’t bought the subscription. Do you guys think it’s worth it? By looking at the post i can see it’s worth it. I have invested about $6k and I’m only making $400 😔 by trading stocks. I’m trying to learn how to trade options',
#        '<@!156274630099861504> need to learn to keep a small amount of positions like you. 🙂 well done',
#        'Based been 🙏',
#        '> <@!613886074921680898> once in a lifetime order haha<@!663395442645663764> yes 🙂',
#        'Cashed out the put side of my GILD straddle today. Time to ride up the call 🙏🏻',
#        'Covered earnings call netted 392% overnight💰🤑',
#        "quick 26% scalp on ZM call, <@!432049873563680786>'s strat  just works 👌🏻",
#        'Whose juicin’ that juice machine w me?!? \U0001f9c3\U0001f9c3\U0001f9c3',
#        'Did my own analysis on CSCO and it turned out well 🔥',
#        'Gains, only down a rack now 🥺🙂',
#        'Lol simulated account because I wanted to swing and missed my ideal entry 😂 yes I used the same amount I would have for a real trade not half a mill',
#        'Thank you big bro <@!579205396166737921> 🤑PUT CITY BITCH',
#        'Can get an annual subscription to Disney+ now 😂',
#        'I can’t trade until tomorrow cause they executed a call 🤬 have to wait omg loosing out on some option action',
#        'My small account. Started with $150 2 weeks ago. Slow and steady 🐢',
#        'the worst of all.. 😄',
#        'damn the week I’m gone and y’all KILLED it! 💪. Miss y’all should be back next week too busy this week but managed to get one trade in',
#        'Y’all played my list better than I did 😂 and thanks for the easy MRNA Gains <@!579205396166737921>',
#        '<@!432049873563680786> awesome signal 🙂',
#        '<@681648845423378455> scroll 👆 to  <@547142824886534174> picture',
#        'Not bad profit for a 1,000 point drop in the market 😂🇺🇸',
#        'Caught a +$10 move on SPY <@!579205396166737921> @Harry <@!464449226521313292> thanks fam 1 super OTM contract 😂',
#        'When the 🐻 shows up, we take his money! Thank you #coronavirus',
#        'posted some thoughts on the BYND trade on the chart - by the way - I HATE BYND! 😂 (for the record - along with AMD, LOL!)',
#        "I'm not going to jinx myself & post my TRIP entry in the profits channel since i didn't close it yet, but I'm sitting on 2 Puts from HOD at 12:21EST. 😉",
#        'Read’em and weep! Thx to Sporadic for this alert 🚨',
#        '> Cutting half of these<@!579205396166737921>  When & where did you alert these? 🧐',
#        'Trust me when I say protection is key 🔑🔥',
#        '> Trade floor yesterday <@676258294175891460><@!579205396166737921>  ok! But is it me or the notifications don’t push through? I believe that all alerts should be alerted through an “Alerts Channel”! It’s very tough to scroll through all chat & put trades in! So much is going on through out the day.. please consider this 🙏🙂',
#        'Learning not to be greedy and take profit before you give it all back 🔥',
#        'Aapl and spy today 😁', 'More money🤤',
#        'You’d be up alot more than 900%...🤔 more like 184,000%',
#        'Woooo <@547142824886534174> that is insane. Well done 👍', '😦',
#        'That second buy was an accident 😂 but you get it lol',
#        'hopefully not today 🙂', 'Took that 💸 and 🏃',
#        'FedEx play insight by <@579205396166737921>  😉😉😉',
#        'Hahha remember when you sent the screenshot yesterday?!  We just had to work that patience buddy 🙏👌💵 great work!',
#        '🐐🐐',
#        '<@586371384289001482> just remember man people can go their whole life without seeing a 30% return in a year and you just did it in a day.  Don’t put yourself down 🤙',
#        '👌 <:blobmuscles:613453963567562754> <:7489_blob_shrek:613455178871603230>',
#        'TTD 30%. Lezzdothis! I hope tomorrow will be a good day! 👌',
#        'Just got to be patient 👌',
#        'Tell me you played NFLX <@385261276986605568> 😂🙏', '😂😂😂',
#        'BANK 🏦', '<@385261276986605568> is in here legit every day 😳😤🔥',
#        'Found this diamond in the rough today 💎 call by <@579205396166737921>  🙏🏻 he just announced some new plays so if you haven’t joined yet it’s not too late to get in on the money!',
#        '😳💪🏿', '🚀',
#        'Easy 30+% in TOL today and she is still going down! <@!623984968921776150> ✊🏻',
#        'How did this happen in one week? 😂😂',
#        'Protection put of SQ called by <@579205396166737921> made money on both sides 😂',
#        '🍻🍻Instagram: kanjosv', '<@!310277096683601920> 🔥',
#        'profits from <@579205396166737921> 🥳 +$300 First Trade after upgrading 💪',
#        'Repositioned a ton hahah but here we go 🤘🔥',
#        '<@!623984968921776150> 🔥', 'Profit is a profit 💰 good stuff',
#        'Exas in, exas out. 😉🤫🚨',
#        '<@579205396166737921> 💯 was filled at the open',
#        'The numbers speak for themselves! 😎📈💰',
#        'Thanks man! All because of the great analysis of our analysts including you. Now I have another $88 for next month’s subscription 👌',
#        '💰💰💰 thanks to our good analysts! Very accurate announcements',
#        '@everyone please tell your friends about our group...  I bought a year long subscription to another group a few months ago and they had DIS calls today after the news and AMD calls yesterday after it already did it’s rip roaring.  We want to help you and everyone else who wants to learn so you don’t make similar mistakes.  Your money is valuable don’t leave to chance please. 🙏',
#        'Good morning everyone 😃', '🔥🔥😳😳',
#        'I need to learn that <@456226577798135808>. Noted 👌', '😂',
#        'Lolol I haven’t actually been investing this month because I’m in the process of moving.  Haha so these callouts are on the house, all of them have been profitable so far, SHOP was up 100% day after callout, TWLO 20% the day after, and NFLX was a grind and would have cut losses but two days after callout it already hit its BEP with 15 days to spare.  APPL was profitable all yesterday and half of today and KO has been profitable all day.  So that’s what we’re working with @everyone Let’s get this money 😉',
#        '🔥🔥🔥', '<@385261276986605568> the legend 👌👌', '😃',
#        'Griffin McDonald’s is all doodoo 😂😂 <@579205396166737921>',
#        '<@385261276986605568> 🦕 thinks you 🐐. My first emojis ever used in a text or chat. Just for baby bro',
#        'Actually more like around 800 😂',
#        'Thanks <@579205396166737921> , now show them ur profits on ULTA. Ballin more than me 😂',
#        '30 minutes Sold 3 keeping 1 💰',
#        'Nice percentage gain for the day 💪🏻',
#        '🔥🔥🔥🔥 thanks for my cheap call <@579205396166737921>',
#        'Yolo baba 😎', '🙏🏻', 'I’m making moves 💰💰💰💯💯',
#        'Lol sent this earlier today but just look at the time😂 where else can you make $7.77 a minute??',
#        'Roku train coming through! Chu chuuuuuu 🚂',
#        'A Benjamin in less than 35 minutes I’ll take it 🤫',
#        'If y’all got some Disney or ROKU profits throw em up fam!!  Good start to the week and more to come 🙏 @everyone',
#        'Let’s go💪🏽 <@586746825298542611>',
#        '@everyone you guys should be really proud of your earnings this week!  Lots of volatility and unpredictability that required lots of patience and everyone stayed cool and made some great money and didn’t stress too much (hopefully).  I could be wrong but I think lots of other groups have trouble making money in an unpredictable market place but you guys are killing it.  Shout out to <@579205396166737921> and <@385261276986605568> for making this possible and here’s to many more weeks like this one 😉',
#        'Nice lil profit 📈', 'MDB Thanks <@!623984968921776150> 🤑',
#        '30% profit 🙏🏼',
#        'A nice pop at the end of the day! <@!623984968921776150> with a great play and still running 🏃',
#        'quick overnight swing 🙂', "We ain't even done with this 😂",
#        'Good day so far, also took profits on BK call from <@!623984968921776150> and SPY puts from <@!319685074784223263>, you guys are awesome 💸',
#        'BA ❤', 'BABA on 🔥 today, still holding some for tomorrow.', '👍',
#        'This is from a <@579205396166737921> earning play way back when. Earnings didn’t go how we wanted but used time and finally got out of LOGI and with a nice profit 🤑',
#        '🔥🔥🔥', '🔥', 'damn that exas play🔥',
#        'Stress-free swinging with 15 days to exp 😎😉 good trading buddy!',
#        'BMY puts, easy profit, <@!623984968921776150> money as usual 💸',
#        'Pretty much paid for membership already👌',
#        '<@!623984968921776150> slight Thursday work 🙏🏻', 'GRMN puts 🔥',
#        'Nice signal by <@!319685074784223263> 💪',
#        'Keeping me sane waiting for twtr. Still cooking  this one 🍳 <@579205396166737921>',
#        '32% profit on free signal from <@!623984968921776150>  on AAL, hope some of the free members got in on this 🏄',
#        '🌊 🏄',
#        'Thanks to <@!623984968921776150> remember a 💯 keeps the doctor away 😂',
#        'that shit been short since May.😆', '👍',
#        'Thanks big bro, great trading! 👍', '👍', '👍',
#        'Sold at these prices 🙂', 'Took profits in EXAS. Thanks boys 😤',
#        '😁', 'Spy Puts from Alex 👀',
#        '<@!623984968921776150> getting it again! 💵', 'Thanks Alex ❤',
#        'Bless 💪🏻',
#        '<@565106328100667393> Strongly agree with you, but I’ll take it. 😁 Just means you’re buying lunch.',
#        '🚼 <@!623984968921776150> <@579205396166737921>',
#        'Omg hahah you did 11/29s 😂😂',
#        'Day traded one of <@!524718950475628554> call outs. ✌🏽',
#        'Baba and Amazon gains with this market dip 😍', '👍',
#        'Like a boss 😎',
#        "Still riding these as i'm out of day trades but hopefully this stays true! Will update tomorrow 🙂",
#        'Hahaha I knew someone would hold PFE 😂👍 well done buddy!',
#        'Thanks <@!623984968921776150> 🚀', '😍😍😍',
#        'He does it again! <@579205396166737921> 🛥s&👩🏼s',
#        'S/O to my man <@!443933735445069825> for the help 🙌',
#        'Still holding. Stay tuned 👀', '🙌🙌 good trading buddy!',
#        'Really good profits today everyone!!🔥', '🚣\u200d♀️ n 👩 s',
#        'The boys are buying cyber trucks after these profits!!! <@579205396166737921> 🔥🔥🚀🚀',
#        'Gains from CGC thanks to <@579205396166737921>   Had a rough start but learned my lessons and plan to start getting in my 💼',
#        '🤷\u200d♂️🤷\u200d♂️🤷\u200d♂️', '👍', '<@!623984968921776150> 🙏🤑',
#        'That xlnx call 😊',
#        '🤷\u200d♂️ grateful for the profit but I will move on', '😎😎😎',
#        "And I'm back to where I started. Let's GOOOO!!! 💰",
#        'Solid plays on ORCL and ZM. S/o out to <@!623984968921776150> and <@!464449226521313292> killin per usual 👌',
#        '👍', 'ORCL from this morning 👀', 'SPOT 🤑', 'Big Gains on Okta 🤑🙏',
#        'Riding that ROKU train too 🚂🔥',
#        'Small account went from 100$ to 500$ just from one signal today 🔥🔥',
#        '🔥', '💯👌', '💪🏽 <@319685074784223263>',
#        'Quick daytrade on NXPI👌 <@!623984968921776150>',
#        '20% gains. Credit to Analyst Alex 🙌',
#        'Quick gains pre earnings on VRTX taking advantage of the options chain 😉 <@579205396166737921>',
#        'I know bro...  I wish I had brokeass money 💰',
#        '<@579205396166737921> does it again! Sold to early this morning but still great return 🤑',
#        '<@!623984968921776150> my man! Already have trimmed some to take profits💰',
#        'Quick Friday trade! S/O to <@!623984968921776150> 💰',
#        'Mcd puts 😒',
#        'Joined Trademate on Friday...already made the membership cost back 😁  Need to work on my weak hands but this is a great start!  Thanks all!',
#        'Another 18% in 40 minutes thanks to <@579205396166737921> 🤙🏼 all the <@&609637319531561007> are amazing',
#        '<@579205396166737921> 🔥', 'Still holding. Strong hands 🖐', '👍',
#        '💯💯🔥', 'Gains credit goes to Austin 💪🏻', '👍', '🕵🏼\u200d♂️',
#        'that 133% gain on BABA i had to take profit🙏', '👍',
#        '1.5 k on pypl 💵💵💵',
#        'Talk about some good management there 👌 👍 💴 💰',
#        'Great job homie 🙌🙏', '👍', '🤷\u200d♂️🤷\u200d♂️🤷\u200d♂️ idc', '😂😂',
#        'Milk the 🐮 likely roll sept & Oct to the Nov 300’s & pull some cash out.',
#        '<@300836254457659392>  signals are 🔥',
#        '```For: Monday, August 31, 2020Symbol                  Qty Cost    Total   Real    PercentReal Open      Close    ------                  --- ----    -----   ----    ----------- ----      -----    AMD 09/18/2020 100.00 C   4 $362.60 $362.60 $114.73 31.64%      8/26/2020 8/26/2020MRVL 10/16/2020 38.00 C   1 $207.67 $207.67 $55.67  26.81%      8/28/2020 8/28/2020IBB 10/16/2020 140.00 C   1 $201.65 $201.65 $99.69  49.44%      8/28/2020 8/28/2020MRVL 10/16/2020 38.00 C   1 $207.67 $207.67 $73.67  35.47%      8/28/2020 8/28/2020IBB 10/16/2020 140.00 C   1 $201.65 $201.65 $71.69  35.55%      8/28/2020 8/28/2020💵 $415.45```',
#        'ZM Some before the 🔔',
#        "Today's goal was $100, made $231. Thanks fam 🙏",
#        'Thanks <@!300836254457659392> 🤩', '<@!329542399841927168> 👍 !',
#        'Only been in this group for a week and it’s already paying off! Thanks <@!300836254457659392> for the AAPL call 🙏🏿',
#        'Quick $150 in 20 min .. 💰 shoutout <@!464449226521313292>',
#        'First day in the group. Green is green 👍',
#        'My second profit after joining Trademate. Gathered my courage to trade this independently using Analyst Bueller’s system. Thank you Trademate for nurturing me into a better trader 🙏🏻',
#        'Gotta keep them fed 🍔', 'TSLA—Feeding the bag holders. 👇🏼',
#        'Holy crap that escalated quickly! <@579205396166737921> 💯 💯 💯',
#        'Thanks <@579205396166737921> !!!! 💯 <:elonohyou:756634750138974208>',
#        'It was a wild ride, <@300836254457659392> but I somehow came out with +$72! 🤣',
#        '👉👌💨', 'Thanks <@752335752376877132> 💯',
#        'Trimmed 4, this was my free runner 🏃💰',
#        '660% from <@579205396166737921> nbd...🤣🤑🤑',
#        'Roth Performance updated. Previously was about 804%. Managed to kick it up a bit on the performance side. Slightly beating the S&P. 😉',
#        'Still running 🏃', '❤️',
#        'Was down 25% EOD yesterday... Been  taught me to have them diamond hands😬',
#        'Got in on <@752335752376877132> signal at a price point I could afford... Not sad about it😬',
#        'Quick $65 in minutes cant complain 🙏🏼',
#        'Performance Check on the Retirement Accounts ✅',
#        'Managed to beat the market by a bit. 🤫',
#        '<@!300836254457659392>  SPY signal for 338C - 💪🏼',
#        'Almost 100% \U0001f9be', '1st day in the group 💪',
#        'I think this is my 2nd or 3rd 100% trade. Thanks <@!579205396166737921> I know I bugged you about this a few times 😄❤️ * had multiple cons',
#        '🥳 🥳', 'Thx <@!579205396166737921> 🙏🏼',
#        'I let this ride a bit higher then rolled the 1750c to the 1800 and added 5 more at the 1900c. On the roll, I pulled 84k out of the trade. These are all essentially free house money plus now. This is the new positioning in play. 👇🏼',
#        'Rolled to this 👇🏼',
#        'Sold one today, swinging this one.  Why am I so stupid not to buy more on Friday! 🤦\u200d♂️ <:spear:613453964599623690>',
#        'Sexy 130-145% today teslas🤩', 'Some PENN action 👇🏼',
#        '<@300836254457659392> 👏', '😳😳👍🍻',
#        'Always feels good to get both sides 🤑', 'Wish I resisted 😅',
#        'Got my 300 percent 🤑', '🥰', 'Thanks 🍎',
#        'APPL 🎉💯<a:countdollars:705781440058753034>',
#        'Thanks <@!300836254457659392> ❤️',
#        'Profits in both my accounts! Swung an AMD Oct 100C and V 212.50C for 9/18. Used profits to do so but awesome day with the group!🤑',
#        "Kindredd's signal on CRM netted me $17.00 from $1.05.   I have a small account (for now 😉 ).  My one month anniversary is tomorrow.  I have been observing from the sidelines.  Thankful and grateful to all at Trademate!",
#        'Trimmed one. <@!300836254457659392> 🙌🏼',
#        'AMD baby thx kindred paid for my other yolos sucking 😂', '💪 🐧',
#        'Got 2300 TSLA call when <@!464449226521313292> called it out on the voice. From $248 to $370 Thank you Austin 😄',
#        'Stay putting in work in voice chat ✊🏾💪🏾',
#        'Made my own call and trade. Took a small little gain on it. Gotta start somewhere with everything learned here.🤑',
#        '🛫', '<@!300836254457659392> gotta watch this guys signals 🔥🔥🔥',
#        '<@!540290732708069393> outstanding accomplishment!! Nice job. 🎊',
#        'Thank you <@!579205396166737921> 🔥🔥🔥 372$', '🥳',
#        'Some NVDA in play 👇🏼', '🤑🤑🤑',
#        '💎 Hands... NOPE!!! What happens when you can’t log into youre acct and it runs. 😂',
#        '✊', '😬😬😬😬', '🤩', 'Theta gang 📉',
#        'This is why u stay cash and jump into plays once u see a good set up 😉 cash is king',
#        'Unity 🤑', 'NIO 💸',
#        "Frfr. It was a spec play in my books so I go light when it's spec plays. 😂😂😂",
#        'Followed the boss man on two of his plays today for 140 dollar lunch money. I don’t believe in ACB but I believe in been 😂 It’s only 10 am. They’re already an open and closed signal for me time to enjoy Veterans Day. <@!579205396166737921>',
#        'my attempt at training my diamond hands to be like pip 😂😭',
#        'Patience pays 😦 couldve held them instead of closing at open for greater profit - nevertheless Ill take it!',
#        'I was tryna hold longer I swear 😂😭',
#        'yessir another one. I do it for trademate ig 🤑🤑',
#        '<@488359813160501251> 🔥',
#        'Finally some green🤠🤠 Just got enough money for another month here on TM <:zuckstocksup:756648506047070259> Thanks to <@!579205396166737921>',
#        "😏😏😏. Had over 50 contracts but I've been scalping out of the position since yesterday",
#        'Actually. Maybe u have 😓', 'Nio 💯', 'Thank you Team 🙏🏼',
#        'A lot of wins 😉',
#        '``` PERCENTAGE GAINS ```Still managing to stay ahead of the S&P gains for the year. 😉',
#        '<@703659646279483503> <@!579205396166737921> 💯🤞🏾',
#        'Fucking ningning 😭👍🏾',
#        'So this was rolled on Nov 25 mid session. 👇🏼',
#        'This is the new position 1 hr into trading. 👇🏼',
#        '<@579205396166737921> not sure why someone bought one of my ACB contracts for 3.7 but I bought it back for $52 less a few minutes later 🤣',
#        'baby gains 🙂', 'ZM 💯', '<@!464449226521313292> 💪🏼💰 thank you',
#        'My ass was clinched so tight I unloaded diamonds 💎 but I held the PLUG and came out with profit <@752335752376877132> <@!300836254457659392>',
#        'don’t judge me I use rh to keep my leaps separate from my day trading account 😂',
#        'Trimmed down from 9. My real cost is 1.62. 💎 hands.',
#        'That tsla L should’ve been an $80 gain but I’m an idiot and thought I filled but I didn’t 😂',
#        'TSLA 💯', '🙏🏼🙏🏼 <@!579205396166737921>', '🙂', 'Almost 2k% 😉😉',
#        "> <@!629362548919107584> don't get too greedy, unrealized until then<@!663395442645663764> yessir. i've been scalping more lol. I like my cold hard cash more then a contract 👀",
#        "> <@!629362548919107584> damn. you're insane with that growth!<@!680245219706667048> i had a bit of luck on my side 🙂",
#        'I need a cash account 😭', '🔥💯',
#        'Thanks <@!579205396166737921>  a cheaper way to play REGN! 💰',
#        'After Trundle tweeted, i took a heavyyy loss on 10/6. Picked up 1 NVDA contract from been.. and completely turned it around the next day. 🔥 🔥 🔥 💰',
#        '🔥', 'Mr Been knows the way.🐳💸',
#        "<@!579205396166737921> Do spreads count toward this high percentage contest? 😆 😆  Here's 900% on that HYLN calendar spread I was talking about yesterday. Somehow got filled here at open!",
#        'AAPL was the move today 👌🏿',
#        'Was camping and this was the only position I had! Was a great trip and printed cmon 🙏🏽🙏🏽 s/o the legend <@!579205396166737921>',
#        '+$400 today 🙂 I’m doing the switch from Robinhood to ToS and it is an ABSOLUTE game changer!',
#        'Thank you @tradingjedi for the awesome swing on AMD 👍🏻👍🏻',
#        'Feeling confident on playing with bigger hands after being in this group for the past couple weeks. This group is amazing 🙏🏿🙌🏿',
#        'Not a bad day. Let’s see if these BBBY swings moon tomorrow 🌙',
#        'TP too early and still walked away with this quick little gem 🤑',
#        'page bouta be flooded w fat snap gains tmo 🤑🤑',
#        'Trades from today ✌🏿', "I'll take it👍", '🍺 Beer Run',
#        'Morning scalp with the fellas in Voice! ✅💰',
#        '<@!579205396166737921> I’ve got a challenge, turn my 2.5k account into 10k 🤣',
#        'Small acc challenge 🤑', 'PTON scalp... thanks Voice Chat. 👍',
#        'APPL leaps.. strong 💪🏻', '😁',
#        "Don't mess with me. I got 6 mcchiekens under my name 👀👀👀",
#        '💪🏼 too easy <@!408072494356889612>', 'Had to let her go 💰💰💰',
#        'Previous pic was thr same. There we go, last one out!😂',
#        'small $ gain but decent % gain 😂 all adds up',
#        '<@!579205396166737921> 🙏🏼 thank you for the 10 min gains',
#        "Trying to recoup those losses on yesterday's end of day signals that I bought based on emotion😂",
#        'MASSIVE GAINS ONLY 😳😳😳', '😉', '🚀', '👌🏿👌🏿', '😉',
#        "2 month of rent 😳😳😳. Don't mind the spellbreak gameplay 😅",
#        'Get in that voice chat!! 🔥', '$634 profit for the day already💰',
#        'Was cheeky and cheap, bought just one call. Thanks <@!524718950475628554>, my subscription is now paid for 😉',
#        'Harry the 🐐',
#        'Opened this account a week ago because I got flagged as a PDT when I lost everything on robinhood during the first downturn 😅. Officially made everything back.',
#        '🥰', 'thank you <@!579205396166737921>  🙌', '🔥 🔥',
#        "I'll be up tomorrow morning for the <@!432049873563680786> hook up haha👀",
#        '🤫',
#        '<@!432049873563680786>  Dude Thank You So Much!! and awesome will do, still new to charting but I can only get better with time 🙏',
#        'Thnx <@579205396166737921>  for spy call 🙏🏻🙏🏻', 'DIS 💨💨',
#        'Trimmed 3 and 7 left. Still printing. Thank you <@579205396166737921>  🙏🏻🙏🏻',
#        'Swung some luv,Bac,dal, spy calls overnight, cashed out right on market open. We take profits.  Time to transfer the rest of this to my new TD Account 👏🏼',
#        '🐐',
#        '> <@!579205396166737921> 🙌🏾<@!284932939039506434> Good shit man. Glad to see you swung it with me!! Paid off very well.',
#        '😭', 'stacking up dem profits 💰💰',
#        'MU moves sooo slowly 😂 but here’s a quick 6% over lunch',
#        'Looking good already 🙂',
#        'Probably the most lit it’s been on a day man ^ <@!579205396166737921> 🔥🔥',
#        'Turns out I sold just before it shot up haha 😅 still a little gain for a little account 🙂',
#        'It’s a paper trade account since I got my money tied up in a down payment for a house 😂.  Took the 5% loss on AMD took a good entry on SPY for 80%+.  Risk management is key, take two or three stops at 5% and then a big gainer when things go right and you make it back in an instant.',
#        'First gain in two weeks 🤧',
#        'I also saw some nice gains on SFIX, and I look great too 😎',
#        'Cashed out these this morning and rebought. I’ll give credit to the rebuy to my boy <@!464449226521313292> 🙏 🙏 💴',
#        'How the heck 😂', 'Thanks for the alert 🚨 👍🏻💴', '🍼',
#        'BKNG — Add more to the retirement account on <@!579205396166737921> favorite play toy. Rolled this to the 1560 May15 and it’s up 25%. And also pulled 2k cash out on the roll. So the new one is a free ride. 😉',
#        'First time scalping solo 🤙',
#        '11% day trade on ZM.  Entered 1/5 of my position and was planning to scale in at each dollar drop from entry but didn’t need to 👍',
#        '😴😴😴', 'Apparently I’m conservatively investing in my ROTH. 👇🏼',
#        'But I beat the S&P 500 Index. 🤣',
#        'Still in these. Will likely exit the short timed ones soon and let the sept’s run. 👇🏼',
#        'Common shares. Spec play on potential merger by Mullen Technologies. (EV space) Still holding. 👇🏼',
#        'China 🇨🇳',
#        'Last of my <#611651674708246644>  recommendation on AMZN 2900/2950 calls  just got filled at $25.  For $2100 in profits on a $390 spread held since Friday 💪 👐  exercise paid off.',
#        'Baby-er scalp than <@579205396166737921> 😋',
#        'Thanks <@!464449226521313292> for the signal 🤙🏼',
#        "Bad entry when <@!464449226521313292> signaled but he wasn't wrong. 💠 hands",
#        'Great day for me 🤙🏼 practiced taking profits when a pt is reached rather than allowing greed to get the best of me.',
#        'Still in these 👇🏼 will look to roll diagonally the July’s. Goal is pull out it $5 as credit is or more. So I’m still deciding where to place them. Decisions.',
#        'Looking for an exit here at $3.00. Charts look like it’s got a bit more to go so I’ll watch closely and squeeze this one a bit more. 👇🏼',
#        'Some TSLA —Looking to roll these out to Mar 21 some place in 1750-1800 and pull out cost plus 75-100% profits. Need a TSLA push to trigger the move. This placement lets me ride thru 3 ER’s. 👇🏼',
#        'Tesla baby 🤑', 'PTON 🧠',
#        'Thank you sir <@!579205396166737921>  62% in 2mins. Trimmed 1. 🙏',
#        '💪 🙌',
#        'Sold 2 earlier at +30%, now 3 remaining at this level.   💪 👐  Been wanting to trade AMZN but it is pricy and could not managed the trade.  Went with Spreads last Friday on the dip to reduce the cost to allow scaling in and trimming out instead of a single call.   Planning to trim down to one to swing on house money into next week.',
#        'ROKU Gains today 💪',
#        'Trimmed 4. Riding 1. Big thanx to my Trading guru <@!579205396166737921> 🙏',
#        '💥💥', '<@!579205396166737921> Thank you sir.,🙏', 'APPL payday 🚀',
#        '🍎 showing love.', 'Few of the AMD positions. Still holding 👇🏼',
#        "<@269575947823349761> I'll show you mine if you show me yours. 😉😏🤑",
#        'AAPL—Tim Cook is a master at supply chains. Looks like the start of a hedge or potential exit from China. 🥳 👇🏼bullish for apple',
#        'Few AMZN longer positions I bought back in Apr for $33 trading now at $453. 👇🏼 still in play.',
#        "Normally aiming for $400 right now, but I'll take it 🙂",
#        '<@!524718950475628554>  is FIRED UP 🔥', 'youre insane 👀',
#        'One of the ADBE positions. Still holding while beast mode continues. 👇🏼',
#        'Still holding. 👇🏼 saw some aggressive insider buying a bit ago so took a follow. So far so good.',
#        '<@397826230424174602> keeping those gains. 💪',
#        'Spreads only $300 small account😋', 'Airlines are back? 🤔',
#        'Sold half at 100% gain and just sold that half 🙂',
#        'Thank you sir for SPY signal 🙏🏻🙏🏻  <@579205396166737921>', '🔥',
#        '3 months in Trademate :) still a lot to learn from this community. Now I have to start trusting myself and push those buttons with multiple contracts cause I play too small LOL. Oh that harsh dip is me doing rookie mistakes lol. Now I know better 🤣',
#        'SPYYYYYYYYY. Thank yousir <@!579205396166737921> 🙏. Trimmed 8. 2 left.',
#        'These haven’t even reached peak yet 🤑🤑', '🧐',
#        'Thank you TradeMate! 🙏',
#        'nothing wrong with getting held down by your dad. also, take your brittle lungs on over to <#646142250027450408> lozer 😏',
#        'good job <@!315710445048692737> 😄',
#        'Made a couple off PTON, nice “call” 😏',
#        '<@579205396166737921>  Thank you so much sir for last hour signals. Learning to scalp too. 🙏🏻🙏🏻',
#        'he wasnt lying when he said he was gonna take the day off from golfing to get the boys paid 🙏 💯',
#        'I ❤️ trademate',
#        '<@!579205396166737921> thank you for trusting sir. 🙏',
#        'SPY 🙏🏻🙏🏻. Since i started trading. Big thanx to sir <@!579205396166737921>. He is the one who is doing it. M nothing. 🙏',
#        '<@432049873563680786>  thanks man. 👍',
#        'Some scalping on SPY.... not as solid exits as my last time but profit is profit 🙂',
#        '🔥🔥🔥🔥🔥🔥',
#        '@ beenpippinsincebeenpippin#4039 👀 just watching your moves 🔥🔥',
#        'Thank you! 🙏🏼', 'Thanks quant bot 🤑',
#        '<#661247978144792596>  Play had a $5 order and it triggered up from $1.38.    For 265% gain really need to work on buying more contracts 🤦\u200d♂️',
#        'Spy and NVDA win! So $311.5 total today 😄', '🤝',
#        'Small play, that I put in late last night during voice chat.  Forgot about it was going to scale in more in the morning.  Taking the profits now at $.80.  Got paid to listen and learn. 👨\u200d🏫 Thanks <@!397826230424174602>',
#        'Making money when the markets is going crazy 😜',
#        '$Dis, interesting 🤔', '$TSLA 💯DIS 💯 Uvxy 💯 QQQ 💯'], dtype=object)

# %%
sia.polarity_scores('When the 🐻 shows up, we take his money! Thank you coronavirus')
# Out:
# {'neg': 0.0, 'neu': 0.782, 'pos': 0.218, 'compound': 0.4199}

# %%
sia.polarity_scores('Not a bad day. Let’s see if these BBBY swings moon tomorrow')
# Out:
# {'neg': 0.0, 'neu': 0.778, 'pos': 0.222, 'compound': 0.431}

# %%
discord_comments_df[discord_comments_df.Emojis != ""].loc[4238, "Message"]
# Out:
# 'First gain in two weeks 🤧'

# %%
discord_emotsent_dict = {'🐠': 0.462,
 '🐟': 0.724,
 '😦': -0.389,
 '🤑': 0.755,
 '🔥': 0.555,
 '😭': -0.093,
 '💦': 0.476,
 '👍': 0.522,
 '💴': 0.25,
 '💰': 0.256,
 '🙂': 0.165,
 '🤯': 0.120,
 '😢': -0.270,
 '🎬': 0.63,
 '😩': -0.368,
 '😅': 0.18,
 '💯': 0.655,
 '😂': 0.221,
 '😎': 0.493,
 '🙌': 0.56,
 '😉': 0.464,
 '👀': 0.163,
 '🤗': 0.456,
 '☝': 0.314,
 '😱': 0.19,
 '🤔': 0.112,
 '🤣': 0.442,
 '😆': 0.412,
 '💥': 0.312,
 '👑': 0.801,
 '🙏': 0.418,
 '😋': 0.634,
 '😘': 0.702,
 '😲': -0.07,
 '🚂': 0.308,
 '😁': 0.45,
 '😔': -0.146,
 '👌': 0.564,
 '\U0001f9c3': 0.265,
 '🥺': -.108,
 '🤬': -.858,
 '🐢': 0.216,
 '😄': 0.422,
 '💪': 0.556,
 '👆': 0.333,
 '🇺': 0.563,
 '🇸': 0.527,
 '🐻': 0.468,
 '🚨': 0.673,
 '🧐': 0.252,
 '🔑': 0.25,
 '🤤': 0.323,
 '💸': 0.567,
 '🏃': 0.415,
 '💵': 0.423,
 '🐐': 0.999,
 '🤙': .425,
 '🏦': 1.0,
 '😳': 0.018,
 '😤': -.211,
 '💎': 0.569,
 '🚀': 0.789,
 '✊': 0.433,
 '🍻': 0.521,
 '🥳': 0.652,
 '🤘': 0.225,
 '🤫': 0.068,
 '📈': 0.745,
 '😃': 0.558,
 '🦕': 0.059,
 '❤': 0.746,
 '🍳': 0.03,
 '🏄': 0.564,
 '🌊': 0.516,
 '🚼': 0.667,
 '✌': 0.464,
 '😍': 0.678,
 '🛥': 0.568,
 '👩': 0.074,
 '🚣': 0.727,
 '♀': 0.333,
 '💼': 0.643,
 '🤷': -.011,
 '♂': 0.2,
 '😊': 0.645,
 '😒': -0.375,
 '🖐': 0.065,
 '🕵': 0.069,
 '🐮': 0.628,
 '🔔': 1.0,
 '🤩': 0.399,
 '🍔': 0.286,
 '👇': 0.255,
 '👉': 0.394,
 '💨': 0.391,
 '😬': 0.196,
 '✅': 0.431,
 '\U0001f9be': 0.228,
 '🤦': -.205,
 '👏': 0.521,
 '🥰': 0.684,
 '🍎': 0.34,
 '🎉': 0.74,
 '🐧': 0.461,
 '🛫': 0.808,
 '🎊': 0.727,
 '📉': 0.5,
 '🤠': 0.670,
 '😏': 0.332,
 '😓': -0.081,
 '🤞': 0.009,
 '🐳': 0.15,
 '🌙': 0.621,
 '🍺': 0.504,
 '🤧': -.182,
 '🍼': 0.625,
 '😴': -0.081,
 '🇨': 0.0,
 '🇳': 0.0,
 '👐': -0.024,
 '💠': 0.113,
 '🧠': 0.602,
 '🤝': .401,
 '👨': 0.571,
 '🏫': 0.300,
 '😜': 0.456}

# %%
vader_values = {}
for emo, sentscore in discord_emotsent_dict.items():
    if sentscore > 0:
        sentscore = sentscore * 3.4
        sentscore = round(sentscore, 1)
        vader_values[emo] = sentscore
    else:
        sentscore = sentscore * 3.9
        sentscore = round(sentscore, 1)
        vader_values[emo] = sentscore

# %%
vader_values
# Out:
# {'🐠': 1.6,
#  '🐟': 2.5,
#  '😦': -1.5,
#  '🤑': 2.6,
#  '🔥': 1.9,
#  '😭': -0.4,
#  '💦': 1.6,
#  '👍': 1.8,
#  '💴': 0.8,
#  '💰': 0.9,
#  '🙂': 0.6,
#  '🤯': 0.4,
#  '😢': -1.1,
#  '🎬': 2.1,
#  '😩': -1.4,
#  '😅': 0.6,
#  '💯': 2.2,
#  '😂': 0.8,
#  '😎': 1.7,
#  '🙌': 1.9,
#  '😉': 1.6,
#  '👀': 0.6,
#  '🤗': 1.6,
#  '☝': 1.1,
#  '😱': 0.6,
#  '🤔': 0.4,
#  '🤣': 1.5,
#  '😆': 1.4,
#  '💥': 1.1,
#  '👑': 2.7,
#  '🙏': 1.4,
#  '😋': 2.2,
#  '😘': 2.4,
#  '😲': -0.3,
#  '🚂': 1.0,
#  '😁': 1.5,
#  '😔': -0.6,
#  '👌': 1.9,
#  '\U0001f9c3': 0.9,
#  '🥺': -0.4,
#  '🤬': -3.3,
#  '🐢': 0.7,
#  '😄': 1.4,
#  '💪': 1.9,
#  '👆': 1.1,
#  '🇺': 1.9,
#  '🇸': 1.8,
#  '🐻': 1.6,
#  '🚨': 2.3,
#  '🧐': 0.9,
#  '🔑': 0.8,
#  '🤤': 1.1,
#  '💸': 1.9,
#  '🏃': 1.4,
#  '💵': 1.4,
#  '🐐': 3.4,
#  '🤙': 1.4,
#  '🏦': 3.4,
#  '😳': 0.1,
#  '😤': -0.8,
#  '💎': 1.9,
#  '🚀': 2.7,
#  '✊': 1.5,
#  '🍻': 1.8,
#  '🥳': 2.2,
#  '🤘': 0.8,
#  '🤫': 0.2,
#  '📈': 2.5,
#  '😃': 1.9,
#  '🦕': 0.2,
#  '❤': 2.5,
#  '🍳': 0.1,
#  '🏄': 1.9,
#  '🌊': 1.8,
#  '🚼': 2.3,
#  '✌': 1.6,
#  '😍': 2.3,
#  '🛥': 1.9,
#  '👩': 0.3,
#  '🚣': 2.5,
#  '♀': 1.1,
#  '💼': 2.2,
#  '🤷': -0.0,
#  '♂': 0.7,
#  '😊': 2.2,
#  '😒': -1.5,
#  '🖐': 0.2,
#  '🕵': 0.2,
#  '🐮': 2.1,
#  '🔔': 3.4,
#  '🤩': 1.4,
#  '🍔': 1.0,
#  '👇': 0.9,
#  '👉': 1.3,
#  '💨': 1.3,
#  '😬': 0.7,
#  '✅': 1.5,
#  '\U0001f9be': 0.8,
#  '🤦': -0.8,
#  '👏': 1.8,
#  '🥰': 2.3,
#  '🍎': 1.2,
#  '🎉': 2.5,
#  '🐧': 1.6,
#  '🛫': 2.7,
#  '🎊': 2.5,
#  '📉': 1.7,
#  '🤠': 2.3,
#  '😏': 1.1,
#  '😓': -0.3,
#  '🤞': 0.0,
#  '🐳': 0.5,
#  '🌙': 2.1,
#  '🍺': 1.7,
#  '🤧': -0.7,
#  '🍼': 2.1,
#  '😴': -0.3,
#  '🇨': 0.0,
#  '🇳': 0.0,
#  '👐': -0.1,
#  '💠': 0.4,
#  '🧠': 2.0,
#  '🤝': 1.4,
#  '👨': 1.9,
#  '🏫': 1.0,
#  '😜': 1.6}

# %%
sia.lexicon.update(vader_values)

# %%
sia.polarity_scores("Hi there this group is good.")
# Out:
# {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'compound': 0.4404}

# %%
sia.lexicon[]
# Out:
# 1.6

# %%
for sen in raw_messages:
    print(sen)
    print("----")
    scores = sia.polarity_scores(sen)
    for k, v in scores.items():
        print(f"{k.upper()} = {v}")
    print("----")
# Out:
# Just keep trimming trimming 🐠 🐟
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# I need some luck to see these gains. 😦
# ----
# NEG = 0.0
# NEU = 0.481
# POS = 0.519
# COMPOUND = 0.6597
# ----
# 10 minutes in that play haha 🤑🤑
# ----
# NEG = 0.0
# NEU = 0.481
# POS = 0.519
# COMPOUND = 0.6597
# ----
# also shoutout to <@!579205396166737921> for the signal 🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# So glad I got on BA😭
# ----
# NEG = 0.0
# NEU = 0.548
# POS = 0.452
# COMPOUND = 0.5095
# ----
# 💦💦💦
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Tried selling but it did not go through 😦
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Jeez nice 👍
# ----
# NEG = 0.0
# NEU = 0.263
# POS = 0.737
# COMPOUND = 0.4215
# ----
# Awesome <@367506726582484996> that’s why your name is purple. Patience pays 💴 💰
# ----
# NEG = 0.0
# NEU = 0.687
# POS = 0.313
# COMPOUND = 0.6249
# ----
# pog 🙂
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# noice 🙂
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 🤯🤯🤯
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# But mine is a negative 😢
# ----
# NEG = 0.552
# NEU = 0.448
# POS = 0.0
# COMPOUND = -0.5719
# ----
# First day wakin up actually n tradin 🎬🎬fuckin movie
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Those look nice!👍
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@579205396166737921> what's the difference between your spy and mine 😩
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@!432049873563680786> thank you for your 🔥🔥FIRE  List everyday!🔥🔥 Chatroom with voicechat and team members is really thatvwork
# ----
# NEG = 0.0
# NEU = 0.838
# POS = 0.162
# COMPOUND = 0.4738
# ----
# Btw I’m j a newbie, only 17yrs old😅
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Made some lunch money while I’m in class 💯 shout-out <@!579205396166737921>
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@!432049873563680786> 👍 learning a lot. Got in on the close of the second candle. Have a lot more to learn still
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# I'm kinda mad that I did a spread instead of naked calls on WORK, But I'll take the $90 profit 🙂
# ----
# NEG = 0.133
# NEU = 0.734
# POS = 0.133
# COMPOUND = -0.0018
# ----
# @<@504078660857364480> Apparently u r not brokeass 😂
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Just keep trimming trimming trimming 🐠 🐟
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@!464449226521313292>  😎
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Made +$26 from SBUX calls, that’s about a 10.6% profit on what I invested.. I’m playing it small and happy with the gains/limit I’ve set myself... Thank you <@!524718950475628554> for the SBUX alert🙌🏻
# ----
# NEG = 0.0
# NEU = 0.707
# POS = 0.293
# COMPOUND = 0.8805
# ----
# Looks good 👍
# ----
# NEG = 0.0
# NEU = 0.256
# POS = 0.744
# COMPOUND = 0.4404
# ----
# hit my daily goal again 😉
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Damn show me the way <@504078660857364480> <:Spitfire:653459285501804582> 🤑
# ----
# NEG = 0.31
# NEU = 0.69
# POS = 0.0
# COMPOUND = -0.4019
# ----
# how did you do it <@!504078660857364480>👀
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Them big boi gainz 🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 30min 410. Ill take it 🤗
# ----
# NEG = 0.412
# NEU = 0.588
# POS = 0.0
# COMPOUND = -0.4215
# ----
# SBUX🔥🔥🔥🔥 let’s goooo <@504078660857364480>
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Gotta thank <@622804945359339543> for this one ☝️
# ----
# NEG = 0.0
# NEU = 0.706
# POS = 0.294
# COMPOUND = 0.3612
# ----
# holy cow with the wow 😱
# ----
# NEG = 0.0
# NEU = 0.513
# POS = 0.487
# COMPOUND = 0.5859
# ----
# <@187734025887023104> Profits from the free signal🔥
# ----
# NEG = 0.0
# NEU = 0.392
# POS = 0.608
# COMPOUND = 0.7351
# ----
# And lulu 😉
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Oh thank you <@597164927265800203> 😂 your pic just made me roll
# ----
# NEG = 0.0
# NEU = 0.783
# POS = 0.217
# COMPOUND = 0.3612
# ----
# From the dis signal, just upgraded 🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 👍
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# This was a no brainer but I still waited till <@!464449226521313292> called it. I held a little longer on my second leg of it so didn’t realize as much gains as he did but what nice profit. 👍🏽 thanks
# ----
# NEG = 0.034
# NEU = 0.647
# POS = 0.319
# COMPOUND = 0.9348
# ----
# (And yes, the right circle IS bigger than the left! picked up two Calls there 😂 )
# ----
# NEG = 0.0
# NEU = 0.824
# POS = 0.176
# COMPOUND = 0.4574
# ----
# Awesome 👍
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 1.0
# COMPOUND = 0.6249
# ----
# Has anyone used indicator script from tradest.io? 🤔🤔🤔is it really that accurate?
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# You are the literal GOAT of the chat 🤣🤣🤣 <@294553563252785152> amazing world man you’re destroying this market no matter the direction
# ----
# NEG = 0.209
# NEU = 0.614
# POS = 0.177
# COMPOUND = -0.2263
# ----
# thanks <@!579205396166737921> & <@!432049873563680786>  - you guys have helped polish this turd right up! 😆
# ----
# NEG = 0.0
# NEU = 0.744
# POS = 0.256
# COMPOUND = 0.5826
# ----
# 😂 😂  im your biggest fan bro <@!294553563252785152>
# ----
# NEG = 0.0
# NEU = 0.659
# POS = 0.341
# COMPOUND = 0.3802
# ----
# Rode the TSLA train up and back down. We have finally surpassed 100k 🙌🏻 Can’t even describe how much this group has changed my life. LETS GO BAYBEEE! #humble #greenisgood
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@!432049873563680786> the strategy works man, simple as that. It fits my style too - I spent the first 6mos of my studying on day trading pennies & quick reversals but PDT killed my game. Enter TM & Bueller’s watch list. BOOM 💥 I can find & manage my own plays everyday (aaand take softballs from your list!) and trade options all day on a cash account with now PDT!
# ----
# NEG = 0.104
# NEU = 0.86
# POS = 0.036
# COMPOUND = -0.7668
# ----
# if you trade my list there are no softballs, its all you! <@!294553563252785152> You have to swing the bat not me 😂  Either way we are an excellent team and I cant wait for next week!
# ----
# NEG = 0.057
# NEU = 0.825
# POS = 0.118
# COMPOUND = 0.5229
# ----
# 👑 <@!149033260016467968>
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Didn’t think ppl would wanna hold their positions over the weekend decided to try 100 on a spy put ended up with 800 😂
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Thank you 🙏 <@!579205396166737921>
# ----
# NEG = 0.0
# NEU = 0.417
# POS = 0.583
# COMPOUND = 0.4199
# ----
# Oops nvm current balance is now $7608.23 🤑
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Talk about a good day 🤑😋 300% gains
# ----
# NEG = 0.0
# NEU = 0.485
# POS = 0.515
# COMPOUND = 0.6486
# ----
# Thanks 🙏 <@!475450165096873987> <@565515276297175070>
# ----
# NEG = 0.0
# NEU = 0.385
# POS = 0.615
# COMPOUND = 0.4926
# ----
# 😘
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# (had to crop the image 🙂 )
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# More than triple the money 🙂 loving BA
# ----
# NEG = 0.0
# NEU = 0.606
# POS = 0.394
# COMPOUND = 0.5994
# ----
# <@!494322262384836624> omg what are you buying? 🙂
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Damn, you guys got quite the rap sheet!!😲😲
# ----
# NEG = 0.319
# NEU = 0.681
# POS = 0.0
# COMPOUND = -0.508
# ----
# Regn train doesn’t stop 🚂 cut my last time. Now I’m letting one ride
# ----
# NEG = 0.281
# NEU = 0.719
# POS = 0.0
# COMPOUND = -0.5106
# ----
# Profit is profit 😁 learned that the hard way
# ----
# NEG = 0.115
# NEU = 0.41
# POS = 0.475
# COMPOUND = 0.6597
# ----
# I just joined this server, and I still haven’t bought the subscription. Do you guys think it’s worth it? By looking at the post i can see it’s worth it. I have invested about $6k and I’m only making $400 😔 by trading stocks. I’m trying to learn how to trade options
# ----
# NEG = 0.0
# NEU = 0.922
# POS = 0.078
# COMPOUND = 0.4215
# ----
# <@!156274630099861504> need to learn to keep a small amount of positions like you. 🙂 well done
# ----
# NEG = 0.0
# NEU = 0.71
# POS = 0.29
# COMPOUND = 0.5983
# ----
# Based been 🙏
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# > <@!613886074921680898> once in a lifetime order haha<@!663395442645663764> yes 🙂
# ----
# NEG = 0.0
# NEU = 0.646
# POS = 0.354
# COMPOUND = 0.508
# ----
# Cashed out the put side of my GILD straddle today. Time to ride up the call 🙏🏻
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Covered earnings call netted 392% overnight💰🤑
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# quick 26% scalp on ZM call, <@!432049873563680786>'s strat  just works 👌🏻
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Whose juicin’ that juice machine w me?!? 🧃🧃🧃
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Did my own analysis on CSCO and it turned out well 🔥
# ----
# NEG = 0.0
# NEU = 0.826
# POS = 0.174
# COMPOUND = 0.2732
# ----
# Gains, only down a rack now 🥺🙂
# ----
# NEG = 0.0
# NEU = 0.676
# POS = 0.324
# COMPOUND = 0.34
# ----
# Lol simulated account because I wanted to swing and missed my ideal entry 😂 yes I used the same amount I would have for a real trade not half a mill
# ----
# NEG = 0.069
# NEU = 0.654
# POS = 0.277
# COMPOUND = 0.7717
# ----
# Thank you big bro <@!579205396166737921> 🤑PUT CITY BITCH
# ----
# NEG = 0.362
# NEU = 0.45
# POS = 0.188
# COMPOUND = -0.5147
# ----
# Can get an annual subscription to Disney+ now 😂
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# I can’t trade until tomorrow cause they executed a call 🤬 have to wait omg loosing out on some option action
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# My small account. Started with $150 2 weeks ago. Slow and steady 🐢
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# the worst of all.. 😄
# ----
# NEG = 0.577
# NEU = 0.423
# POS = 0.0
# COMPOUND = -0.6249
# ----
# damn the week I’m gone and y’all KILLED it! 💪. Miss y’all should be back next week too busy this week but managed to get one trade in
# ----
# NEG = 0.208
# NEU = 0.792
# POS = 0.0
# COMPOUND = -0.6766
# ----
# Y’all played my list better than I did 😂 and thanks for the easy MRNA Gains <@!579205396166737921>
# ----
# NEG = 0.0
# NEU = 0.42
# POS = 0.58
# COMPOUND = 0.9151
# ----
# <@!432049873563680786> awesome signal 🙂
# ----
# NEG = 0.0
# NEU = 0.313
# POS = 0.687
# COMPOUND = 0.6588
# ----
# <@681648845423378455> scroll 👆 to  <@547142824886534174> picture
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Not bad profit for a 1,000 point drop in the market 😂🇺🇸
# ----
# NEG = 0.293
# NEU = 0.521
# POS = 0.186
# COMPOUND = -0.167
# ----
# Caught a +$10 move on SPY <@!579205396166737921> @Harry <@!464449226521313292> thanks fam 1 super OTM contract 😂
# ----
# NEG = 0.0
# NEU = 0.598
# POS = 0.402
# COMPOUND = 0.8118
# ----
# When the 🐻 shows up, we take his money! Thank you #coronavirus
# ----
# NEG = 0.0
# NEU = 0.782
# POS = 0.218
# COMPOUND = 0.4199
# ----
# posted some thoughts on the BYND trade on the chart - by the way - I HATE BYND! 😂 (for the record - along with AMD, LOL!)
# ----
# NEG = 0.193
# NEU = 0.807
# POS = 0.0
# COMPOUND = -0.7199
# ----
# I'm not going to jinx myself & post my TRIP entry in the profits channel since i didn't close it yet, but I'm sitting on 2 Puts from HOD at 12:21EST. 😉
# ----
# NEG = 0.0
# NEU = 0.933
# POS = 0.067
# COMPOUND = 0.2382
# ----
# Read’em and weep! Thx to Sporadic for this alert 🚨
# ----
# NEG = 0.247
# NEU = 0.4
# POS = 0.353
# COMPOUND = 0.1511
# ----
# > Cutting half of these<@!579205396166737921>  When & where did you alert these? 🧐
# ----
# NEG = 0.125
# NEU = 0.667
# POS = 0.208
# COMPOUND = 0.2481
# ----
# Trust me when I say protection is key 🔑🔥
# ----
# NEG = 0.0
# NEU = 0.68
# POS = 0.32
# COMPOUND = 0.5106
# ----
# > Trade floor yesterday <@676258294175891460><@!579205396166737921>  ok! But is it me or the notifications don’t push through? I believe that all alerts should be alerted through an “Alerts Channel”! It’s very tough to scroll through all chat & put trades in! So much is going on through out the day.. please consider this 🙏🙂
# ----
# NEG = 0.033
# NEU = 0.863
# POS = 0.104
# COMPOUND = 0.596
# ----
# Learning not to be greedy and take profit before you give it all back 🔥
# ----
# NEG = 0.0
# NEU = 0.712
# POS = 0.288
# COMPOUND = 0.5943
# ----
# Aapl and spy today 😁
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# More money🤤
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# You’d be up alot more than 900%...🤔 more like 184,000%
# ----
# NEG = 0.0
# NEU = 0.763
# POS = 0.237
# COMPOUND = 0.4201
# ----
# Woooo <@547142824886534174> that is insane. Well done 👍
# ----
# NEG = 0.276
# NEU = 0.51
# POS = 0.214
# COMPOUND = -0.1531
# ----
# 😦
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# That second buy was an accident 😂 but you get it lol
# ----
# NEG = 0.139
# NEU = 0.61
# POS = 0.251
# COMPOUND = 0.3919
# ----
# hopefully not today 🙂
# ----
# NEG = 0.0
# NEU = 0.426
# POS = 0.574
# COMPOUND = 0.4019
# ----
# Took that 💸 and 🏃
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# FedEx play insight by <@579205396166737921>  😉😉😉
# ----
# NEG = 0.0
# NEU = 0.676
# POS = 0.324
# COMPOUND = 0.34
# ----
# Hahha remember when you sent the screenshot yesterday?!  We just had to work that patience buddy 🙏👌💵 great work!
# ----
# NEG = 0.0
# NEU = 0.794
# POS = 0.206
# COMPOUND = 0.6892
# ----
# 🐐🐐
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@586371384289001482> just remember man people can go their whole life without seeing a 30% return in a year and you just did it in a day.  Don’t put yourself down 🤙
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 👌 <:blobmuscles:613453963567562754> <:7489_blob_shrek:613455178871603230>
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# TTD 30%. Lezzdothis! I hope tomorrow will be a good day! 👌
# ----
# NEG = 0.0
# NEU = 0.523
# POS = 0.477
# COMPOUND = 0.7494
# ----
# Just got to be patient 👌
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Tell me you played NFLX <@385261276986605568> 😂🙏
# ----
# NEG = 0.0
# NEU = 0.714
# POS = 0.286
# COMPOUND = 0.34
# ----
# 😂😂😂
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# BANK 🏦
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@385261276986605568> is in here legit every day 😳😤🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Found this diamond in the rough today 💎 call by <@579205396166737921>  🙏🏻 he just announced some new plays so if you haven’t joined yet it’s not too late to get in on the money!
# ----
# NEG = 0.0
# NEU = 0.869
# POS = 0.131
# COMPOUND = 0.5707
# ----
# 😳💪🏿
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 🚀
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Easy 30+% in TOL today and she is still going down! <@!623984968921776150> ✊🏻
# ----
# NEG = 0.0
# NEU = 0.775
# POS = 0.225
# COMPOUND = 0.5399
# ----
# How did this happen in one week? 😂😂
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Protection put of SQ called by <@579205396166737921> made money on both sides 😂
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 🍻🍻Instagram: kanjosv
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@!310277096683601920> 🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# profits from <@579205396166737921> 🥳 +$300 First Trade after upgrading 💪
# ----
# NEG = 0.0
# NEU = 0.707
# POS = 0.293
# COMPOUND = 0.4404
# ----
# Repositioned a ton hahah but here we go 🤘🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@!623984968921776150> 🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Profit is a profit 💰 good stuff
# ----
# NEG = 0.0
# NEU = 0.187
# POS = 0.813
# COMPOUND = 0.8271
# ----
# Exas in, exas out. 😉🤫🚨
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@579205396166737921> 💯 was filled at the open
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# The numbers speak for themselves! 😎📈💰
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Thanks man! All because of the great analysis of our analysts including you. Now I have another $88 for next month’s subscription 👌
# ----
# NEG = 0.0
# NEU = 0.723
# POS = 0.277
# COMPOUND = 0.807
# ----
# 💰💰💰 thanks to our good analysts! Very accurate announcements
# ----
# NEG = 0.0
# NEU = 0.535
# POS = 0.465
# COMPOUND = 0.7263
# ----
# @everyone please tell your friends about our group...  I bought a year long subscription to another group a few months ago and they had DIS calls today after the news and AMD calls yesterday after it already did it’s rip roaring.  We want to help you and everyone else who wants to learn so you don’t make similar mistakes.  Your money is valuable don’t leave to chance please. 🙏
# ----
# NEG = 0.048
# NEU = 0.732
# POS = 0.22
# COMPOUND = 0.9022
# ----
# Good morning everyone 😃
# ----
# NEG = 0.0
# NEU = 0.408
# POS = 0.592
# COMPOUND = 0.4404
# ----
# 🔥🔥😳😳
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# I need to learn that <@456226577798135808>. Noted 👌
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 😂
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Lolol I haven’t actually been investing this month because I’m in the process of moving.  Haha so these callouts are on the house, all of them have been profitable so far, SHOP was up 100% day after callout, TWLO 20% the day after, and NFLX was a grind and would have cut losses but two days after callout it already hit its BEP with 15 days to spare.  APPL was profitable all yesterday and half of today and KO has been profitable all day.  So that’s what we’re working with @everyone Let’s get this money 😉
# ----
# NEG = 0.033
# NEU = 0.853
# POS = 0.114
# COMPOUND = 0.85
# ----
# 🔥🔥🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@385261276986605568> the legend 👌👌
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 😃
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Griffin McDonald’s is all doodoo 😂😂 <@579205396166737921>
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@385261276986605568> 🦕 thinks you 🐐. My first emojis ever used in a text or chat. Just for baby bro
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Actually more like around 800 😂
# ----
# NEG = 0.0
# NEU = 0.589
# POS = 0.411
# COMPOUND = 0.4201
# ----
# Thanks <@579205396166737921> , now show them ur profits on ULTA. Ballin more than me 😂
# ----
# NEG = 0.0
# NEU = 0.655
# POS = 0.345
# COMPOUND = 0.7003
# ----
# 30 minutes Sold 3 keeping 1 💰
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Nice percentage gain for the day 💪🏻
# ----
# NEG = 0.0
# NEU = 0.446
# POS = 0.554
# COMPOUND = 0.7351
# ----
# 🔥🔥🔥🔥 thanks for my cheap call <@579205396166737921>
# ----
# NEG = 0.0
# NEU = 0.674
# POS = 0.326
# COMPOUND = 0.4404
# ----
# Yolo baba 😎
# ----
# NEG = 0.0
# NEU = 0.323
# POS = 0.677
# COMPOUND = 0.2732
# ----
# 🙏🏻
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# I’m making moves 💰💰💰💯💯
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Lol sent this earlier today but just look at the time😂 where else can you make $7.77 a minute??
# ----
# NEG = 0.0
# NEU = 0.883
# POS = 0.117
# COMPOUND = 0.3094
# ----
# Roku train coming through! Chu chuuuuuu 🚂
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# A Benjamin in less than 35 minutes I’ll take it 🤫
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# If y’all got some Disney or ROKU profits throw em up fam!!  Good start to the week and more to come 🙏 @everyone
# ----
# NEG = 0.0
# NEU = 0.758
# POS = 0.242
# COMPOUND = 0.7494
# ----
# Let’s go💪🏽 <@586746825298542611>
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# @everyone you guys should be really proud of your earnings this week!  Lots of volatility and unpredictability that required lots of patience and everyone stayed cool and made some great money and didn’t stress too much (hopefully).  I could be wrong but I think lots of other groups have trouble making money in an unpredictable market place but you guys are killing it.  Shout out to <@579205396166737921> and <@385261276986605568> for making this possible and here’s to many more weeks like this one 😉
# ----
# NEG = 0.145
# NEU = 0.75
# POS = 0.105
# COMPOUND = -0.703
# ----
# Nice lil profit 📈
# ----
# NEG = 0.0
# NEU = 0.149
# POS = 0.851
# COMPOUND = 0.6908
# ----
# MDB Thanks <@!623984968921776150> 🤑
# ----
# NEG = 0.0
# NEU = 0.385
# POS = 0.615
# COMPOUND = 0.4926
# ----
# 30% profit 🙏🏼
# ----
# NEG = 0.0
# NEU = 0.408
# POS = 0.592
# COMPOUND = 0.4404
# ----
# A nice pop at the end of the day! <@!623984968921776150> with a great play and still running 🏃
# ----
# NEG = 0.0
# NEU = 0.548
# POS = 0.452
# COMPOUND = 0.8715
# ----
# quick overnight swing 🙂
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# We ain't even done with this 😂
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Good day so far, also took profits on BK call from <@!623984968921776150> and SPY puts from <@!319685074784223263>, you guys are awesome 💸
# ----
# NEG = 0.0
# NEU = 0.632
# POS = 0.368
# COMPOUND = 0.8881
# ----
# BA ❤
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# BABA on 🔥 today, still holding some for tomorrow.
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 👍
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# This is from a <@579205396166737921> earning play way back when. Earnings didn’t go how we wanted but used time and finally got out of LOGI and with a nice profit 🤑
# ----
# NEG = 0.0
# NEU = 0.73
# POS = 0.27
# COMPOUND = 0.85
# ----
# 🔥🔥🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 🔥
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# damn that exas play🔥
# ----
# NEG = 0.474
# NEU = 0.526
# POS = 0.0
# COMPOUND = -0.4019
# ----
# Stress-free swinging with 15 days to exp 😎😉 good trading buddy!
# ----
# NEG = 0.0
# NEU = 0.758
# POS = 0.242
# COMPOUND = 0.4926
# ----
# BMY puts, easy profit, <@!623984968921776150> money as usual 💸
# ----
# NEG = 0.0
# NEU = 0.496
# POS = 0.504
# COMPOUND = 0.7263
# ----
# Pretty much paid for membership already👌
# ----
# NEG = 0.0
# NEU = 0.61
# POS = 0.39
# COMPOUND = 0.4939
# ----
# <@!623984968921776150> slight Thursday work 🙏🏻
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# GRMN puts 🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Nice signal by <@!319685074784223263> 💪
# ----
# NEG = 0.0
# NEU = 0.492
# POS = 0.508
# COMPOUND = 0.4753
# ----
# Keeping me sane waiting for twtr. Still cooking  this one 🍳 <@579205396166737921>
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 32% profit on free signal from <@!623984968921776150>  on AAL, hope some of the free members got in on this 🏄
# ----
# NEG = 0.0
# NEU = 0.542
# POS = 0.458
# COMPOUND = 0.9134
# ----
# 🌊 🏄
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Thanks to <@!623984968921776150> remember a 💯 keeps the doctor away 😂
# ----
# NEG = 0.0
# NEU = 0.687
# POS = 0.313
# COMPOUND = 0.4926
# ----
# that shit been short since May.😆
# ----
# NEG = 0.419
# NEU = 0.581
# POS = 0.0
# COMPOUND = -0.5574
# ----
# 👍
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Thanks big bro, great trading! 👍
# ----
# NEG = 0.0
# NEU = 0.291
# POS = 0.709
# COMPOUND = 0.807
# ----
# 👍
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 👍
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Sold at these prices 🙂
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Took profits in EXAS. Thanks boys 😤
# ----
# NEG = 0.0
# NEU = 0.408
# POS = 0.592
# COMPOUND = 0.7003
# ----
# 😁
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Spy Puts from Alex 👀
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@!623984968921776150> getting it again! 💵
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Thanks Alex ❤
# ----
# NEG = 0.0
# NEU = 0.256
# POS = 0.744
# COMPOUND = 0.4404
# ----
# Bless 💪🏻
# ----
# NEG = 0.0
# NEU = 0.263
# POS = 0.737
# COMPOUND = 0.4215
# ----
# <@565106328100667393> Strongly agree with you, but I’ll take it. 😁 Just means you’re buying lunch.
# ----
# NEG = 0.0
# NEU = 0.784
# POS = 0.216
# COMPOUND = 0.3182
# ----
# 🚼 <@!623984968921776150> <@579205396166737921>
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Omg hahah you did 11/29s 😂😂
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Day traded one of <@!524718950475628554> call outs. ✌🏽
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Baba and Amazon gains with this market dip 😍
# ----
# NEG = 0.0
# NEU = 0.594
# POS = 0.406
# COMPOUND = 0.4767
# ----
# 👍
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Like a boss 😎
# ----
# NEG = 0.0
# NEU = 0.286
# POS = 0.714
# COMPOUND = 0.3612
# ----
# Still riding these as i'm out of day trades but hopefully this stays true! Will update tomorrow 🙂
# ----
# NEG = 0.0
# NEU = 0.665
# POS = 0.335
# COMPOUND = 0.8197
# ----
# Hahaha I knew someone would hold PFE 😂👍 well done buddy!
# ----
# NEG = 0.0
# NEU = 0.572
# POS = 0.428
# COMPOUND = 0.7177
# ----
# Thanks <@!623984968921776150> 🚀
# ----
# NEG = 0.0
# NEU = 0.239
# POS = 0.761
# COMPOUND = 0.4926
# ----
# 😍😍😍
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# He does it again! <@579205396166737921> 🛥s&👩🏼s
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# S/O to my man <@!443933735445069825> for the help 🙌
# ----
# NEG = 0.0
# NEU = 0.701
# POS = 0.299
# COMPOUND = 0.4574
# ----
# Still holding. Stay tuned 👀
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 🙌🙌 good trading buddy!
# ----
# NEG = 0.0
# NEU = 0.484
# POS = 0.516
# COMPOUND = 0.4926
# ----
# Really good profits today everyone!!🔥
# ----
# NEG = 0.0
# NEU = 0.301
# POS = 0.699
# COMPOUND = 0.7879
# ----
# 🚣‍♀️ n 👩 s
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# The boys are buying cyber trucks after these profits!!! <@579205396166737921> 🔥🔥🚀🚀
# ----
# NEG = 0.0
# NEU = 0.726
# POS = 0.274
# COMPOUND = 0.5826
# ----
# Gains from CGC thanks to <@579205396166737921>   Had a rough start but learned my lessons and plan to start getting in my 💼
# ----
# NEG = 0.0
# NEU = 0.831
# POS = 0.169
# COMPOUND = 0.3919
# ----
# 🤷‍♂️🤷‍♂️🤷‍♂️
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 👍
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@!623984968921776150> 🙏🤑
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# That xlnx call 😊
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 🤷‍♂️ grateful for the profit but I will move on
# ----
# NEG = 0.0
# NEU = 0.639
# POS = 0.361
# COMPOUND = 0.4497
# ----
# 😎😎😎
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# And I'm back to where I started. Let's GOOOO!!! 💰
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Solid plays on ORCL and ZM. S/o out to <@!623984968921776150> and <@!464449226521313292> killin per usual 👌
# ----
# NEG = 0.0
# NEU = 0.757
# POS = 0.243
# COMPOUND = 0.4912
# ----
# 👍
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# ORCL from this morning 👀
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# SPOT 🤑
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Big Gains on Okta 🤑🙏
# ----
# NEG = 0.0
# NEU = 0.625
# POS = 0.375
# COMPOUND = 0.34
# ----
# Riding that ROKU train too 🚂🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Small account went from 100$ to 500$ just from one signal today 🔥🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 🔥
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 💯👌
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 💪🏽 <@319685074784223263>
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Quick daytrade on NXPI👌 <@!623984968921776150>
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 20% gains. Credit to Analyst Alex 🙌
# ----
# NEG = 0.0
# NEU = 0.444
# POS = 0.556
# COMPOUND = 0.6124
# ----
# Quick gains pre earnings on VRTX taking advantage of the options chain 😉 <@579205396166737921>
# ----
# NEG = 0.0
# NEU = 0.714
# POS = 0.286
# COMPOUND = 0.5267
# ----
# I know bro...  I wish I had brokeass money 💰
# ----
# NEG = 0.0
# NEU = 0.649
# POS = 0.351
# COMPOUND = 0.4019
# ----
# <@579205396166737921> does it again! Sold to early this morning but still great return 🤑
# ----
# NEG = 0.0
# NEU = 0.669
# POS = 0.331
# COMPOUND = 0.7871
# ----
# <@!623984968921776150> my man! Already have trimmed some to take profits💰
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Quick Friday trade! S/O to <@!623984968921776150> 💰
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Mcd puts 😒
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Joined Trademate on Friday...already made the membership cost back 😁  Need to work on my weak hands but this is a great start!  Thanks all!
# ----
# NEG = 0.061
# NEU = 0.624
# POS = 0.315
# COMPOUND = 0.8788
# ----
# Another 18% in 40 minutes thanks to <@579205396166737921> 🤙🏼 all the <@&609637319531561007> are amazing
# ----
# NEG = 0.0
# NEU = 0.642
# POS = 0.358
# COMPOUND = 0.7717
# ----
# <@579205396166737921> 🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Still holding. Strong hands 🖐
# ----
# NEG = 0.0
# NEU = 0.476
# POS = 0.524
# COMPOUND = 0.5106
# ----
# 👍
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 💯💯🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Gains credit goes to Austin 💪🏻
# ----
# NEG = 0.0
# NEU = 0.444
# POS = 0.556
# COMPOUND = 0.6124
# ----
# 👍
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 🕵🏼‍♂️
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# that 133% gain on BABA i had to take profit🙏
# ----
# NEG = 0.0
# NEU = 0.702
# POS = 0.298
# COMPOUND = 0.5267
# ----
# 👍
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 1.5 k on pypl 💵💵💵
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Talk about some good management there 👌 👍 💴 💰
# ----
# NEG = 0.0
# NEU = 0.633
# POS = 0.367
# COMPOUND = 0.4404
# ----
# Great job homie 🙌🙏
# ----
# NEG = 0.0
# NEU = 0.423
# POS = 0.577
# COMPOUND = 0.6249
# ----
# 👍
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 🤷‍♂️🤷‍♂️🤷‍♂️ idc
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 😂😂
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Milk the 🐮 likely roll sept & Oct to the Nov 300’s & pull some cash out.
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@300836254457659392>  signals are 🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# ```For: Monday, August 31, 2020Symbol                  Qty Cost    Total   Real    PercentReal Open      Close    ------                  --- ----    -----   ----    ----------- ----      -----    AMD 09/18/2020 100.00 C   4 $362.60 $362.60 $114.73 31.64%      8/26/2020 8/26/2020MRVL 10/16/2020 38.00 C   1 $207.67 $207.67 $55.67  26.81%      8/28/2020 8/28/2020IBB 10/16/2020 140.00 C   1 $201.65 $201.65 $99.69  49.44%      8/28/2020 8/28/2020MRVL 10/16/2020 38.00 C   1 $207.67 $207.67 $73.67  35.47%      8/28/2020 8/28/2020IBB 10/16/2020 140.00 C   1 $201.65 $201.65 $71.69  35.55%      8/28/2020 8/28/2020💵 $415.45```
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# ZM Some before the 🔔
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Today's goal was $100, made $231. Thanks fam 🙏
# ----
# NEG = 0.0
# NEU = 0.707
# POS = 0.293
# COMPOUND = 0.4404
# ----
# Thanks <@!300836254457659392> 🤩
# ----
# NEG = 0.0
# NEU = 0.239
# POS = 0.761
# COMPOUND = 0.4926
# ----
# <@!329542399841927168> 👍 !
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Only been in this group for a week and it’s already paying off! Thanks <@!300836254457659392> for the AAPL call 🙏🏿
# ----
# NEG = 0.0
# NEU = 0.838
# POS = 0.162
# COMPOUND = 0.5399
# ----
# Quick $150 in 20 min .. 💰 shoutout <@!464449226521313292>
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# First day in the group. Green is green 👍
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# My second profit after joining Trademate. Gathered my courage to trade this independently using Analyst Bueller’s system. Thank you Trademate for nurturing me into a better trader 🙏🏻
# ----
# NEG = 0.0
# NEU = 0.603
# POS = 0.397
# COMPOUND = 0.926
# ----
# Gotta keep them fed 🍔
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# TSLA—Feeding the bag holders. 👇🏼
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Holy crap that escalated quickly! <@579205396166737921> 💯 💯 💯
# ----
# NEG = 0.366
# NEU = 0.634
# POS = 0.0
# COMPOUND = -0.4389
# ----
# Thanks <@579205396166737921> !!!! 💯 <:elonohyou:756634750138974208>
# ----
# NEG = 0.0
# NEU = 0.424
# POS = 0.576
# COMPOUND = 0.6209
# ----
# It was a wild ride, <@300836254457659392> but I somehow came out with +$72! 🤣
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 👉👌💨
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Thanks <@752335752376877132> 💯
# ----
# NEG = 0.0
# NEU = 0.256
# POS = 0.744
# COMPOUND = 0.4404
# ----
# Trimmed 4, this was my free runner 🏃💰
# ----
# NEG = 0.0
# NEU = 0.68
# POS = 0.32
# COMPOUND = 0.5106
# ----
# 660% from <@579205396166737921> nbd...🤣🤑🤑
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Roth Performance updated. Previously was about 804%. Managed to kick it up a bit on the performance side. Slightly beating the S&P. 😉
# ----
# NEG = 0.119
# NEU = 0.881
# POS = 0.0
# COMPOUND = -0.4033
# ----
# Still running 🏃
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# ❤️
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Was down 25% EOD yesterday... Been  taught me to have them diamond hands😬
# ----
# NEG = 0.0
# NEU = 0.833
# POS = 0.167
# COMPOUND = 0.34
# ----
# Got in on <@752335752376877132> signal at a price point I could afford... Not sad about it😬
# ----
# NEG = 0.0
# NEU = 0.836
# POS = 0.164
# COMPOUND = 0.3724
# ----
# Quick $65 in minutes cant complain 🙏🏼
# ----
# NEG = 0.0
# NEU = 0.74
# POS = 0.26
# COMPOUND = 0.2755
# ----
# Performance Check on the Retirement Accounts ✅
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Managed to beat the market by a bit. 🤫
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@!300836254457659392>  SPY signal for 338C - 💪🏼
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Almost 100% 🦾
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 1st day in the group 💪
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# I think this is my 2nd or 3rd 100% trade. Thanks <@!579205396166737921> I know I bugged you about this a few times 😄❤️ * had multiple cons
# ----
# NEG = 0.0
# NEU = 0.868
# POS = 0.132
# COMPOUND = 0.4926
# ----
# 🥳 🥳
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Thx <@!579205396166737921> 🙏🏼
# ----
# NEG = 0.0
# NEU = 0.417
# POS = 0.583
# COMPOUND = 0.4199
# ----
# I let this ride a bit higher then rolled the 1750c to the 1800 and added 5 more at the 1900c. On the roll, I pulled 84k out of the trade. These are all essentially free house money plus now. This is the new positioning in play. 👇🏼
# ----
# NEG = 0.0
# NEU = 0.881
# POS = 0.119
# COMPOUND = 0.6908
# ----
# Rolled to this 👇🏼
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Sold one today, swinging this one.  Why am I so stupid not to buy more on Friday! 🤦‍♂️ <:spear:613453964599623690>
# ----
# NEG = 0.215
# NEU = 0.785
# POS = 0.0
# COMPOUND = -0.6867
# ----
# Sexy 130-145% today teslas🤩
# ----
# NEG = 0.0
# NEU = 0.469
# POS = 0.531
# COMPOUND = 0.5267
# ----
# Some PENN action 👇🏼
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@300836254457659392> 👏
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 😳😳👍🍻
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Always feels good to get both sides 🤑
# ----
# NEG = 0.0
# NEU = 0.674
# POS = 0.326
# COMPOUND = 0.4404
# ----
# Wish I resisted 😅
# ----
# NEG = 0.0
# NEU = 0.27
# POS = 0.73
# COMPOUND = 0.4019
# ----
# Got my 300 percent 🤑
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 🥰
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Thanks 🍎
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 1.0
# COMPOUND = 0.4404
# ----
# APPL 🎉💯<a:countdollars:705781440058753034>
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Thanks <@!300836254457659392> ❤️
# ----
# NEG = 0.0
# NEU = 0.385
# POS = 0.615
# COMPOUND = 0.4926
# ----
# Profits in both my accounts! Swung an AMD Oct 100C and V 212.50C for 9/18. Used profits to do so but awesome day with the group!🤑
# ----
# NEG = 0.0
# NEU = 0.676
# POS = 0.324
# COMPOUND = 0.8898
# ----
# Kindredd's signal on CRM netted me $17.00 from $1.05.   I have a small account (for now 😉 ).  My one month anniversary is tomorrow.  I have been observing from the sidelines.  Thankful and grateful to all at Trademate!
# ----
# NEG = 0.0
# NEU = 0.821
# POS = 0.179
# COMPOUND = 0.7901
# ----
# Trimmed one. <@!300836254457659392> 🙌🏼
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# AMD baby thx kindred paid for my other yolos sucking 😂
# ----
# NEG = 0.0
# NEU = 0.783
# POS = 0.217
# COMPOUND = 0.3612
# ----
# 💪 🐧
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Got 2300 TSLA call when <@!464449226521313292> called it out on the voice. From $248 to $370 Thank you Austin 😄
# ----
# NEG = 0.0
# NEU = 0.866
# POS = 0.134
# COMPOUND = 0.4199
# ----
# Stay putting in work in voice chat ✊🏾💪🏾
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Made my own call and trade. Took a small little gain on it. Gotta start somewhere with everything learned here.🤑
# ----
# NEG = 0.0
# NEU = 0.853
# POS = 0.147
# COMPOUND = 0.4779
# ----
# 🛫
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@!300836254457659392> gotta watch this guys signals 🔥🔥🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@!540290732708069393> outstanding accomplishment!! Nice job. 🎊
# ----
# NEG = 0.0
# NEU = 0.281
# POS = 0.719
# COMPOUND = 0.826
# ----
# Thank you <@!579205396166737921> 🔥🔥🔥 372$
# ----
# NEG = 0.0
# NEU = 0.589
# POS = 0.411
# COMPOUND = 0.4199
# ----
# 🥳
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Some NVDA in play 👇🏼
# ----
# NEG = 0.0
# NEU = 0.625
# POS = 0.375
# COMPOUND = 0.34
# ----
# 🤑🤑🤑
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 💎 Hands... NOPE!!! What happens when you can’t log into youre acct and it runs. 😂
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# ✊
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 😬😬😬😬
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 🤩
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Theta gang 📉
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# This is why u stay cash and jump into plays once u see a good set up 😉 cash is king
# ----
# NEG = 0.0
# NEU = 0.754
# POS = 0.246
# COMPOUND = 0.5994
# ----
# Unity 🤑
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# NIO 💸
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Frfr. It was a spec play in my books so I go light when it's spec plays. 😂😂😂
# ----
# NEG = 0.0
# NEU = 0.761
# POS = 0.239
# COMPOUND = 0.5267
# ----
# Followed the boss man on two of his plays today for 140 dollar lunch money. I don’t believe in ACB but I believe in been 😂 It’s only 10 am. They’re already an open and closed signal for me time to enjoy Veterans Day. <@!579205396166737921>
# ----
# NEG = 0.0
# NEU = 0.868
# POS = 0.132
# COMPOUND = 0.7263
# ----
# my attempt at training my diamond hands to be like pip 😂😭
# ----
# NEG = 0.0
# NEU = 0.671
# POS = 0.329
# COMPOUND = 0.5994
# ----
# Patience pays 😦 couldve held them instead of closing at open for greater profit - nevertheless Ill take it!
# ----
# NEG = 0.124
# NEU = 0.622
# POS = 0.253
# COMPOUND = 0.4389
# ----
# I was tryna hold longer I swear 😂😭
# ----
# NEG = 0.194
# NEU = 0.806
# POS = 0.0
# COMPOUND = -0.0516
# ----
# yessir another one. I do it for trademate ig 🤑🤑
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@488359813160501251> 🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Finally some green🤠🤠 Just got enough money for another month here on TM <:zuckstocksup:756648506047070259> Thanks to <@!579205396166737921>
# ----
# NEG = 0.0
# NEU = 0.834
# POS = 0.166
# COMPOUND = 0.4926
# ----
# 😏😏😏. Had over 50 contracts but I've been scalping out of the position since yesterday
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Actually. Maybe u have 😓
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Nio 💯
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Thank you Team 🙏🏼
# ----
# NEG = 0.0
# NEU = 0.545
# POS = 0.455
# COMPOUND = 0.3612
# ----
# A lot of wins 😉
# ----
# NEG = 0.0
# NEU = 0.351
# POS = 0.649
# COMPOUND = 0.5719
# ----
# ``` PERCENTAGE GAINS ```Still managing to stay ahead of the S&P gains for the year. 😉
# ----
# NEG = 0.0
# NEU = 0.701
# POS = 0.299
# COMPOUND = 0.6739
# ----
# <@703659646279483503> <@!579205396166737921> 💯🤞🏾
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Fucking ningning 😭👍🏾
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# So this was rolled on Nov 25 mid session. 👇🏼
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# This is the new position 1 hr into trading. 👇🏼
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@579205396166737921> not sure why someone bought one of my ACB contracts for 3.7 but I bought it back for $52 less a few minutes later 🤣
# ----
# NEG = 0.063
# NEU = 0.937
# POS = 0.0
# COMPOUND = -0.1232
# ----
# baby gains 🙂
# ----
# NEG = 0.0
# NEU = 0.294
# POS = 0.706
# COMPOUND = 0.34
# ----
# ZM 💯
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@!464449226521313292> 💪🏼💰 thank you
# ----
# NEG = 0.0
# NEU = 0.518
# POS = 0.482
# COMPOUND = 0.4199
# ----
# My ass was clinched so tight I unloaded diamonds 💎 but I held the PLUG and came out with profit <@752335752376877132> <@!300836254457659392>
# ----
# NEG = 0.096
# NEU = 0.727
# POS = 0.177
# COMPOUND = 0.4389
# ----
# don’t judge me I use rh to keep my leaps separate from my day trading account 😂
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Trimmed down from 9. My real cost is 1.62. 💎 hands.
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# That tsla L should’ve been an $80 gain but I’m an idiot and thought I filled but I didn’t 😂
# ----
# NEG = 0.215
# NEU = 0.678
# POS = 0.107
# COMPOUND = -0.5023
# ----
# TSLA 💯
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 🙏🏼🙏🏼 <@!579205396166737921>
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 🙂
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Almost 2k% 😉😉
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# > <@!629362548919107584> don't get too greedy, unrealized until then<@!663395442645663764> yessir. i've been scalping more lol. I like my cold hard cash more then a contract 👀
# ----
# NEG = 0.05
# NEU = 0.647
# POS = 0.303
# COMPOUND = 0.7916
# ----
# > <@!629362548919107584> damn. you're insane with that growth!<@!680245219706667048> i had a bit of luck on my side 🙂
# ----
# NEG = 0.31
# NEU = 0.543
# POS = 0.148
# COMPOUND = -0.5067
# ----
# I need a cash account 😭
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 🔥💯
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Thanks <@!579205396166737921>  a cheaper way to play REGN! 💰
# ----
# NEG = 0.0
# NEU = 0.459
# POS = 0.541
# COMPOUND = 0.7081
# ----
# After Trundle tweeted, i took a heavyyy loss on 10/6. Picked up 1 NVDA contract from been.. and completely turned it around the next day. 🔥 🔥 🔥 💰
# ----
# NEG = 0.099
# NEU = 0.901
# POS = 0.0
# COMPOUND = -0.3182
# ----
# 🔥
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Mr Been knows the way.🐳💸
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@!579205396166737921> Do spreads count toward this high percentage contest? 😆 😆  Here's 900% on that HYLN calendar spread I was talking about yesterday. Somehow got filled here at open!
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# AAPL was the move today 👌🏿
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Was camping and this was the only position I had! Was a great trip and printed cmon 🙏🏽🙏🏽 s/o the legend <@!579205396166737921>
# ----
# NEG = 0.0
# NEU = 0.802
# POS = 0.198
# COMPOUND = 0.6892
# ----
# +$400 today 🙂 I’m doing the switch from Robinhood to ToS and it is an ABSOLUTE game changer!
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Thank you @tradingjedi for the awesome swing on AMD 👍🏻👍🏻
# ----
# NEG = 0.0
# NEU = 0.548
# POS = 0.452
# COMPOUND = 0.765
# ----
# Feeling confident on playing with bigger hands after being in this group for the past couple weeks. This group is amazing 🙏🏿🙌🏿
# ----
# NEG = 0.0
# NEU = 0.636
# POS = 0.364
# COMPOUND = 0.8519
# ----
# Not a bad day. Let’s see if these BBBY swings moon tomorrow 🌙
# ----
# NEG = 0.0
# NEU = 0.778
# POS = 0.222
# COMPOUND = 0.431
# ----
# TP too early and still walked away with this quick little gem 🤑
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# page bouta be flooded w fat snap gains tmo 🤑🤑
# ----
# NEG = 0.0
# NEU = 0.769
# POS = 0.231
# COMPOUND = 0.34
# ----
# Trades from today ✌🏿
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# I'll take it👍
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 🍺 Beer Run
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Morning scalp with the fellas in Voice! ✅💰
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@!579205396166737921> I’ve got a challenge, turn my 2.5k account into 10k 🤣
# ----
# NEG = 0.0
# NEU = 0.85
# POS = 0.15
# COMPOUND = 0.1511
# ----
# Small acc challenge 🤑
# ----
# NEG = 0.0
# NEU = 0.606
# POS = 0.394
# COMPOUND = 0.0772
# ----
# PTON scalp... thanks Voice Chat. 👍
# ----
# NEG = 0.0
# NEU = 0.58
# POS = 0.42
# COMPOUND = 0.4404
# ----
# APPL leaps.. strong 💪🏻
# ----
# NEG = 0.0
# NEU = 0.476
# POS = 0.524
# COMPOUND = 0.5106
# ----
# 😁
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Don't mess with me. I got 6 mcchiekens under my name 👀👀👀
# ----
# NEG = 0.0
# NEU = 0.81
# POS = 0.19
# COMPOUND = 0.2755
# ----
# 💪🏼 too easy <@!408072494356889612>
# ----
# NEG = 0.0
# NEU = 0.484
# POS = 0.516
# COMPOUND = 0.4926
# ----
# Had to let her go 💰💰💰
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Previous pic was thr same. There we go, last one out!😂
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# small $ gain but decent % gain 😂 all adds up
# ----
# NEG = 0.0
# NEU = 0.469
# POS = 0.531
# COMPOUND = 0.7783
# ----
# <@!579205396166737921> 🙏🏼 thank you for the 10 min gains
# ----
# NEG = 0.0
# NEU = 0.574
# POS = 0.426
# COMPOUND = 0.636
# ----
# Trying to recoup those losses on yesterday's end of day signals that I bought based on emotion😂
# ----
# NEG = 0.153
# NEU = 0.847
# POS = 0.0
# COMPOUND = -0.4019
# ----
# MASSIVE GAINS ONLY 😳😳😳
# ----
# NEG = 0.0
# NEU = 0.489
# POS = 0.511
# COMPOUND = 0.4824
# ----
# 😉
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 🚀
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 👌🏿👌🏿
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 😉
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 2 month of rent 😳😳😳. Don't mind the spellbreak gameplay 😅
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Get in that voice chat!! 🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# $634 profit for the day already💰
# ----
# NEG = 0.0
# NEU = 0.633
# POS = 0.367
# COMPOUND = 0.4404
# ----
# Was cheeky and cheap, bought just one call. Thanks <@!524718950475628554>, my subscription is now paid for 😉
# ----
# NEG = 0.0
# NEU = 0.825
# POS = 0.175
# COMPOUND = 0.4926
# ----
# Harry the 🐐
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Opened this account a week ago because I got flagged as a PDT when I lost everything on robinhood during the first downturn 😅. Officially made everything back.
# ----
# NEG = 0.091
# NEU = 0.909
# POS = 0.0
# COMPOUND = -0.3182
# ----
# 🥰
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# thank you <@!579205396166737921>  🙌
# ----
# NEG = 0.0
# NEU = 0.417
# POS = 0.583
# COMPOUND = 0.4199
# ----
# 🔥 🔥
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# I'll be up tomorrow morning for the <@!432049873563680786> hook up haha👀
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 🤫
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@!432049873563680786>  Dude Thank You So Much!! and awesome will do, still new to charting but I can only get better with time 🙏
# ----
# NEG = 0.0
# NEU = 0.663
# POS = 0.337
# COMPOUND = 0.8465
# ----
# Thnx <@579205396166737921>  for spy call 🙏🏻🙏🏻
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# DIS 💨💨
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Trimmed 3 and 7 left. Still printing. Thank you <@579205396166737921>  🙏🏻🙏🏻
# ----
# NEG = 0.0
# NEU = 0.762
# POS = 0.238
# COMPOUND = 0.3612
# ----
# Swung some luv,Bac,dal, spy calls overnight, cashed out right on market open. We take profits.  Time to transfer the rest of this to my new TD Account 👏🏼
# ----
# NEG = 0.0
# NEU = 0.903
# POS = 0.097
# COMPOUND = 0.4404
# ----
# 🐐
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# > <@!579205396166737921> 🙌🏾<@!284932939039506434> Good shit man. Glad to see you swung it with me!! Paid off very well.
# ----
# NEG = 0.138
# NEU = 0.499
# POS = 0.363
# COMPOUND = 0.706
# ----
# 😭
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# stacking up dem profits 💰💰
# ----
# NEG = 0.0
# NEU = 0.58
# POS = 0.42
# COMPOUND = 0.4404
# ----
# MU moves sooo slowly 😂 but here’s a quick 6% over lunch
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Looking good already 🙂
# ----
# NEG = 0.0
# NEU = 0.408
# POS = 0.592
# COMPOUND = 0.4404
# ----
# Probably the most lit it’s been on a day man ^ <@!579205396166737921> 🔥🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Turns out I sold just before it shot up haha 😅 still a little gain for a little account 🙂
# ----
# NEG = 0.0
# NEU = 0.68
# POS = 0.32
# COMPOUND = 0.7275
# ----
# It’s a paper trade account since I got my money tied up in a down payment for a house 😂.  Took the 5% loss on AMD took a good entry on SPY for 80%+.  Risk management is key, take two or three stops at 5% and then a big gainer when things go right and you make it back in an instant.
# ----
# NEG = 0.099
# NEU = 0.854
# POS = 0.048
# COMPOUND = -0.2732
# ----
# First gain in two weeks 🤧
# ----
# NEG = 0.0
# NEU = 0.541
# POS = 0.459
# COMPOUND = 0.5267
# ----
# I also saw some nice gains on SFIX, and I look great too 😎
# ----
# NEG = 0.0
# NEU = 0.462
# POS = 0.538
# COMPOUND = 0.8519
# ----
# Cashed out these this morning and rebought. I’ll give credit to the rebuy to my boy <@!464449226521313292> 🙏 🙏 💴
# ----
# NEG = 0.0
# NEU = 0.847
# POS = 0.153
# COMPOUND = 0.4389
# ----
# How the heck 😂
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Thanks for the alert 🚨 👍🏻💴
# ----
# NEG = 0.0
# NEU = 0.37
# POS = 0.63
# COMPOUND = 0.6249
# ----
# 🍼
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# BKNG — Add more to the retirement account on <@!579205396166737921> favorite play toy. Rolled this to the 1560 May15 and it’s up 25%. And also pulled 2k cash out on the roll. So the new one is a free ride. 😉
# ----
# NEG = 0.0
# NEU = 0.796
# POS = 0.204
# COMPOUND = 0.8398
# ----
# First time scalping solo 🤙
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 11% day trade on ZM.  Entered 1/5 of my position and was planning to scale in at each dollar drop from entry but didn’t need to 👍
# ----
# NEG = 0.058
# NEU = 0.942
# POS = 0.0
# COMPOUND = -0.1406
# ----
# 😴😴😴
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Apparently I’m conservatively investing in my ROTH. 👇🏼
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# But I beat the S&P 500 Index. 🤣
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Still in these. Will likely exit the short timed ones soon and let the sept’s run. 👇🏼
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Common shares. Spec play on potential merger by Mullen Technologies. (EV space) Still holding. 👇🏼
# ----
# NEG = 0.0
# NEU = 0.739
# POS = 0.261
# COMPOUND = 0.5574
# ----
# China 🇨🇳
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Last of my <#611651674708246644>  recommendation on AMZN 2900/2950 calls  just got filled at $25.  For $2100 in profits on a $390 spread held since Friday 💪 👐  exercise paid off.
# ----
# NEG = 0.0
# NEU = 0.9
# POS = 0.1
# COMPOUND = 0.4404
# ----
# Baby-er scalp than <@579205396166737921> 😋
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Thanks <@!464449226521313292> for the signal 🤙🏼
# ----
# NEG = 0.0
# NEU = 0.61
# POS = 0.39
# COMPOUND = 0.4926
# ----
# Bad entry when <@!464449226521313292> signaled but he wasn't wrong. 💠 hands
# ----
# NEG = 0.162
# NEU = 0.577
# POS = 0.261
# COMPOUND = 0.3341
# ----
# Great day for me 🤙🏼 practiced taking profits when a pt is reached rather than allowing greed to get the best of me.
# ----
# NEG = 0.084
# NEU = 0.526
# POS = 0.39
# COMPOUND = 0.872
# ----
# Still in these 👇🏼 will look to roll diagonally the July’s. Goal is pull out it $5 as credit is or more. So I’m still deciding where to place them. Decisions.
# ----
# NEG = 0.0
# NEU = 0.92
# POS = 0.08
# COMPOUND = 0.3818
# ----
# Looking for an exit here at $3.00. Charts look like it’s got a bit more to go so I’ll watch closely and squeeze this one a bit more. 👇🏼
# ----
# NEG = 0.0
# NEU = 0.912
# POS = 0.088
# COMPOUND = 0.3612
# ----
# Some TSLA —Looking to roll these out to Mar 21 some place in 1750-1800 and pull out cost plus 75-100% profits. Need a TSLA push to trigger the move. This placement lets me ride thru 3 ER’s. 👇🏼
# ----
# NEG = 0.0
# NEU = 0.923
# POS = 0.077
# COMPOUND = 0.4404
# ----
# Tesla baby 🤑
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# PTON 🧠
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Thank you sir <@!579205396166737921>  62% in 2mins. Trimmed 1. 🙏
# ----
# NEG = 0.0
# NEU = 0.741
# POS = 0.259
# COMPOUND = 0.4199
# ----
# 💪 🙌
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Sold 2 earlier at +30%, now 3 remaining at this level.   💪 👐  Been wanting to trade AMZN but it is pricy and could not managed the trade.  Went with Spreads last Friday on the dip to reduce the cost to allow scaling in and trimming out instead of a single call.   Planning to trim down to one to swing on house money into next week.
# ----
# NEG = 0.0
# NEU = 0.962
# POS = 0.038
# COMPOUND = 0.3291
# ----
# ROKU Gains today 💪
# ----
# NEG = 0.0
# NEU = 0.455
# POS = 0.545
# COMPOUND = 0.34
# ----
# Trimmed 4. Riding 1. Big thanx to my Trading guru <@!579205396166737921> 🙏
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 💥💥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@!579205396166737921> Thank you sir.,🙏
# ----
# NEG = 0.0
# NEU = 0.518
# POS = 0.482
# COMPOUND = 0.4199
# ----
# APPL payday 🚀
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 🍎 showing love.
# ----
# NEG = 0.0
# NEU = 0.192
# POS = 0.808
# COMPOUND = 0.6369
# ----
# Few of the AMD positions. Still holding 👇🏼
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@269575947823349761> I'll show you mine if you show me yours. 😉😏🤑
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# AAPL—Tim Cook is a master at supply chains. Looks like the start of a hedge or potential exit from China. 🥳 👇🏼bullish for apple
# ----
# NEG = 0.0
# NEU = 0.889
# POS = 0.111
# COMPOUND = 0.3612
# ----
# Few AMZN longer positions I bought back in Apr for $33 trading now at $453. 👇🏼 still in play.
# ----
# NEG = 0.0
# NEU = 0.876
# POS = 0.124
# COMPOUND = 0.34
# ----
# Normally aiming for $400 right now, but I'll take it 🙂
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@!524718950475628554>  is FIRED UP 🔥
# ----
# NEG = 0.607
# NEU = 0.393
# POS = 0.0
# COMPOUND = -0.6833
# ----
# youre insane 👀
# ----
# NEG = 0.73
# NEU = 0.27
# POS = 0.0
# COMPOUND = -0.4019
# ----
# One of the ADBE positions. Still holding while beast mode continues. 👇🏼
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Still holding. 👇🏼 saw some aggressive insider buying a bit ago so took a follow. So far so good.
# ----
# NEG = 0.077
# NEU = 0.726
# POS = 0.197
# COMPOUND = 0.5378
# ----
# <@397826230424174602> keeping those gains. 💪
# ----
# NEG = 0.0
# NEU = 0.556
# POS = 0.444
# COMPOUND = 0.34
# ----
# Spreads only $300 small account😋
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Airlines are back? 🤔
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Sold half at 100% gain and just sold that half 🙂
# ----
# NEG = 0.0
# NEU = 0.726
# POS = 0.274
# COMPOUND = 0.5267
# ----
# Thank you sir for SPY signal 🙏🏻🙏🏻  <@579205396166737921>
# ----
# NEG = 0.0
# NEU = 0.737
# POS = 0.263
# COMPOUND = 0.3612
# ----
# 🔥
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# 3 months in Trademate :) still a lot to learn from this community. Now I have to start trusting myself and push those buttons with multiple contracts cause I play too small LOL. Oh that harsh dip is me doing rookie mistakes lol. Now I know better 🤣
# ----
# NEG = 0.095
# NEU = 0.599
# POS = 0.306
# COMPOUND = 0.8986
# ----
# SPYYYYYYYYY. Thank yousir <@!579205396166737921> 🙏. Trimmed 8. 2 left.
# ----
# NEG = 0.0
# NEU = 0.715
# POS = 0.285
# COMPOUND = 0.4199
# ----
# These haven’t even reached peak yet 🤑🤑
# ----
# NEG = 0.0
# NEU = 0.811
# POS = 0.189
# COMPOUND = 0.1027
# ----
# 🧐
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Thank you TradeMate! 🙏
# ----
# NEG = 0.0
# NEU = 0.417
# POS = 0.583
# COMPOUND = 0.4199
# ----
# nothing wrong with getting held down by your dad. also, take your brittle lungs on over to <#646142250027450408> lozer 😏
# ----
# NEG = 0.0
# NEU = 0.876
# POS = 0.124
# COMPOUND = 0.3724
# ----
# good job <@!315710445048692737> 😄
# ----
# NEG = 0.0
# NEU = 0.385
# POS = 0.615
# COMPOUND = 0.4926
# ----
# Made a couple off PTON, nice “call” 😏
# ----
# NEG = 0.0
# NEU = 0.641
# POS = 0.359
# COMPOUND = 0.4215
# ----
# <@579205396166737921>  Thank you so much sir for last hour signals. Learning to scalp too. 🙏🏻🙏🏻
# ----
# NEG = 0.0
# NEU = 0.848
# POS = 0.152
# COMPOUND = 0.3612
# ----
# he wasnt lying when he said he was gonna take the day off from golfing to get the boys paid 🙏 💯
# ----
# NEG = 0.0
# NEU = 0.873
# POS = 0.127
# COMPOUND = 0.4168
# ----
# I ❤️ trademate
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@!579205396166737921> thank you for trusting sir. 🙏
# ----
# NEG = 0.0
# NEU = 0.421
# POS = 0.579
# COMPOUND = 0.6696
# ----
# SPY 🙏🏻🙏🏻. Since i started trading. Big thanx to sir <@!579205396166737921>. He is the one who is doing it. M nothing. 🙏
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# <@432049873563680786>  thanks man. 👍
# ----
# NEG = 0.0
# NEU = 0.408
# POS = 0.592
# COMPOUND = 0.4404
# ----
# Some scalping on SPY.... not as solid exits as my last time but profit is profit 🙂
# ----
# NEG = 0.056
# NEU = 0.593
# POS = 0.351
# COMPOUND = 0.8165
# ----
# 🔥🔥🔥🔥🔥🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# @ beenpippinsincebeenpippin#4039 👀 just watching your moves 🔥🔥
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Thank you! 🙏🏼
# ----
# NEG = 0.0
# NEU = 0.417
# POS = 0.583
# COMPOUND = 0.4199
# ----
# Thanks quant bot 🤑
# ----
# NEG = 0.0
# NEU = 0.408
# POS = 0.592
# COMPOUND = 0.4404
# ----
# <#661247978144792596>  Play had a $5 order and it triggered up from $1.38.    For 265% gain really need to work on buying more contracts 🤦‍♂️
# ----
# NEG = 0.0
# NEU = 0.784
# POS = 0.216
# COMPOUND = 0.7003
# ----
# Spy and NVDA win! So $311.5 total today 😄
# ----
# NEG = 0.0
# NEU = 0.631
# POS = 0.369
# COMPOUND = 0.6239
# ----
# 🤝
# ----
# NEG = 0.0
# NEU = 0.0
# POS = 0.0
# COMPOUND = 0.0
# ----
# Small play, that I put in late last night during voice chat.  Forgot about it was going to scale in more in the morning.  Taking the profits now at $.80.  Got paid to listen and learn. 👨‍🏫 Thanks <@!397826230424174602>
# ----
# NEG = 0.0
# NEU = 0.805
# POS = 0.195
# COMPOUND = 0.8172
# ----
# Making money when the markets is going crazy 😜
# ----
# NEG = 0.255
# NEU = 0.745
# POS = 0.0
# COMPOUND = -0.34
# ----
# $Dis, interesting 🤔
# ----
# NEG = 0.0
# NEU = 0.27
# POS = 0.73
# COMPOUND = 0.4019
# ----
# $TSLA 💯DIS 💯 Uvxy 💯 QQQ 💯
# ----
# NEG = 0.0
# NEU = 1.0
# POS = 0.0
# COMPOUND = 0.0
# ----

# %%
sia.polarity_scores("Jeez nice")
# Out:
# {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}

# %%
sia.polarity_scores("Thomps")
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
sia.lexicon.update({"thomps": 2.3})

# %%
sia.polarity_scores("I made some lunch money")
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
sia.lexicon["((-:"]
# Out:
# 2.1
